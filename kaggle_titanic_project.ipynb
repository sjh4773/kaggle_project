# %% [markdown]
# - [Overview](#overview)
#     - [Etiquette](#etiquette)
#
# - [Feature Engineering](#feature_engineering)
#     - [(1) Data Import](#data_import)
#     - [(2) Matplotlib Color & Default Setting](#data_combine)
#     - [(3) Data Visualization](#handling_missing_values)
#     - [(4) Feature Encoding](#feature_encoding)
#     - [(5) Split Data](#split_data)
#     - [(6) Limitation](#limitation)
#
# - [Scikit Learn](#scikit_learn)
#     - [(1) Data Split](#data_split)
#     - [(2) Base Model - Decision Tree](#base_model_tree)
#     - [(3) Create Helper Class and Submission Function](#helper_class)
#         * [(A) DecisionTreeClassifier](#DecisionTreeClassifier)
#         * [(B) RandomForestClassifier](#RandomForestClassifier)
#         * [(C) LightGBM](#lightgbm)
#         * [(D) Feature Importance](#feature_importance)
#         * [(E) Submission](#submission)
#
# - [PyCaret](#pycaret)
#     - [(1) Intro](#intro)
#     - [(2) PyCaret Tutorials](#pycaret_tutorials)
#     - [(3) Base Model](#base_model)
#         + [(A) Initialize Setup](#initialize_setup)
#         + [(B) Comparing All Models](#compare_models)
#         + [(C) Create Model](#create_pycaret_model)
#         + [(D) Tune Model](#tune_pycaret_model)
#         + [(E) Plot Model](#plot_pycaret_model)
#         + [(F) Predictions and Submissions](#preds_submissions)
#
# > If you want to know how to create table of contents in Kaggle Notebooks, please check this article [Create Table of Contents in a Notebook](https://www.kaggle.com/dcstang/create-table-of-contents-in-a-notebook) by David Tang

# %% [markdown]
# <a id="overview"></a>
# ## Overview
# - This is my personal tutorial sharing with my students as example.
# - The whole processes will be shared from EDA to Modeling and Evaluation, Finally Submission.
#     + Let's Check My [EDA Code](https://www.kaggle.com/j2hoon85/2021-april-play-ground-eda-for-kaggle-newbies)
# - The well-known notebooks shared will be enough for students to learn Kaggle as an entry level.
#
# > Happy to Code

# %% [markdown]
# <a id='etiquette'></a>
# ### Etiquette
# - When students get codes and ideas from other notebooks, then please make sure to leave a reference and upvote it as well. 👆👆👆

# %% [markdown]
# <a id="feature_engineering"></a>
# ## Feature Engineering
# - After EDA, it's time to conduct Feature Engineering.
# - If you are not familiar with this concept, then please read a book
#
# ![Feature Engineering for Machine Learning](https://learning.oreilly.com/library/cover/9781491953235/250w/)
#
# - And If you need a short summary about feature engineering, then please check this article as well.
#     + [@Chris Deotte Feature Engineering Techniques](https://www.kaggle.com/c/ieee-fraud-detection/discussion/108575)

# %% [markdown]
# <a id='data_import'></a>
# ### (1) Data Import
# - Let's get datasets

# %%
from sklearn.preprocessing import LabelEncoder
import lightgbm
from lightgbm import LGBMClassifier
from sklearn.model_selection import KFold
from tqdm import tqdm
import matplotlib.pyplot as plt 
from sklearn.metrics import accuracy_score,roc_auc_score

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc,os,sys
import random

from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_colwidth', 30)

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
# !mkdir ~/.kaggle
# !echo '{"username": "{username}", "key" : "key"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle competitions list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes        127           False
# gan-getting-started                            2030-07-01 23:59:00  Getting Started     Prizes        234           False
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge        764           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       4033           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      32968            True
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       8571            True
# connectx                                       2030-01-01 00:00:00  Getting Started  Knowledge        706           False
# nlp-getting-started                            2030-01-01 00:00:00  Getting Started  Knowledge       2318            True
# competitive-data-science-predict-future-sales  2022-12-31 23:59:00  Playground           Kudos      10976           False
# jane-street-market-prediction                  2021-08-23 23:59:00  Featured          $100,000       4245           False
# hungry-geese                                   2021-07-26 23:59:00  Playground          Prizes        532           False
# coleridgeinitiative-show-us-the-data           2021-06-22 23:59:00  Featured           $90,000        616           False
# bms-molecular-translation                      2021-06-02 23:59:00  Featured           $50,000        513           False
# birdclef-2021                                  2021-05-31 23:59:00  Research            $5,000        257           False
# iwildcam2021-fgvc8                             2021-05-26 23:59:00  Research         Knowledge         23           False
# herbarium-2021-fgvc8                           2021-05-26 23:59:00  Research         Knowledge         45           False
# plant-pathology-2021-fgvc8                     2021-05-26 23:59:00  Research         Knowledge        295           False
# hotel-id-2021-fgvc8                            2021-05-26 23:59:00  Research         Knowledge         58           False
# hashcode-2021-oqr-extension                    2021-05-25 23:59:00  Playground       Knowledge        128           False
# indoor-location-navigation                     2021-05-17 23:59:00  Research           $10,000        959           False

# %%
# !kaggle competitions download -c tabular-playground-series-apr-2021
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# sample_data	       test.csv      train.csv
# sample_submission.csv  test.csv.zip  train.csv.zip

# %%
# !unzip train.csv.zip
# !unzip test.csv.zip
# Out:
# Archive:  train.csv.zip
# replace train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: train.csv
# Archive:  test.csv.zip
# replace test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: test.csv

# %%
train = pd.read_csv('./train.csv')
test= pd.read_csv('./test.csv')
sample_submission = pd.read_csv('./sample_submission.csv')

train.shape, test.shape, sample_submission.shape
# Out:
# ((100000, 12), (100000, 11), (100000, 2))

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass              Name   Sex    Age  SibSp  Parch  \
# 0            0         1       1  Oconnor, Frankie  male    NaN      2      0
# 1            1         0       3       Bryan, Drew  male    NaN      0      0
# 2            2         0       3    Owens, Kenneth  male   0.33      1      2
# 3            3         0       3     Kramer, James  male  19.00      0      0
# 4            4         1       3     Bond, Michael  male  25.00      0      0
#
#       Ticket   Fare   Cabin Embarked
# 0     209245  27.14  C12239        S
# 1      27323  13.35     NaN        S
# 2  CA 457703  71.29     NaN        S
# 3   A. 10866  13.04     NaN        S
# 4     427635   7.76     NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass              Name     Sex   Age  SibSp  Parch  Ticket  \
# 0       100000       3  Holliday, Daniel    male  19.0      0      0   24745
# 1       100001       3  Nguyen, Lorraine  female  53.0      0      0   13264
# 2       100002       1   Harris, Heather  female  19.0      0      0   25990
# 3       100003       2      Larsen, Eric    male  25.0      0      0  314011
# 4       100004       1     Cleary, Sarah  female  17.0      0      2   26203
#
#     Fare   Cabin Embarked
# 0  63.01     NaN        S
# 1   5.81     NaN        S
# 2  38.91  B15315        C
# 3  12.93     NaN        S
# 4  26.89  B22515        C

# %%
sample_submission.head()
# Out:
#    PassengerId  Survived
# 0       100000         1
# 1       100001         1
# 2       100002         1
# 3       100003         1
# 4       100004         1

# %%
train.dtypes[train.dtypes != 'object'].index.tolist()
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# ### (2)Matplotlib Color & Default Setting

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
print(mpl.__version__)
# Out:
# 3.4.1

# %%
from cycler import cycler

mpl.rcParams['figure.dpi'] = 120
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
# mpl.rcParams['font.family'] = 'serif'

raw_light_palette = [
    (0, 122, 255), # Blue
    (255, 149, 0), # Orange
    (52, 199, 89), # Green
    (255, 59, 48), # Red
    (175, 82, 222),# Purple
    (255, 45, 85), # Pink
    (88, 86, 214), # Indigo
    (90, 200, 250),# Teal
    (255, 204, 0)  # Yellow
]

light_palette = np.array(raw_light_palette)/255


mpl.rcParams['axes.prop_cycle'] = cycler('color',light_palette)

survived_palette = ['#dddddd', mpl.colors.to_hex(light_palette[2])]

sex_palette = [light_palette[0], light_palette[3]]

# %% [markdown]
# ### (3)Data visualization

# %%
fig = plt.figure(figsize=(15, 11))

gs = fig.add_gridspec(3, 4) # row size * column size 형태의 1차원 어레이, subplot 사이즈 조절. 한 화면을 3 x 4 형태로 분할한다고 생각하면 됨.




ax_sex_survived = fig.add_subplot(gs[:2,:2])
sns.countplot(x='Sex',hue='Survived', data=train, ax=ax_sex_survived, 
              palette=survived_palette)

ax_survived_sex = fig.add_subplot(gs[:2,2:4], sharey=ax_sex_survived)
sns.countplot(x='Survived',hue='Sex', data=train, ax=ax_survived_sex,
              palette=sex_palette
             )

# ax_survived_sex.set_yticks([])
ax_survived_sex.set_ylabel('')

ax_pie_male = fig.add_subplot(gs[2, 0])
ax_pie_female = fig.add_subplot(gs[2, 1])
ax_pie_notsurvived = fig.add_subplot(gs[2, 2])
ax_pie_survived = fig.add_subplot(gs[2, 3])

# Sex
male = train[train['Sex']=='male']['Survived'].value_counts().sort_index()
ax_pie_male.pie(male, labels=male.index, autopct='%1.1f%%',explode = (0, 0.1), startangle=90,
               colors=survived_palette
               )


female = train[train['Sex']=='female']['Survived'].value_counts().sort_index()
ax_pie_female.pie(female, labels=female.index, autopct='%1.1f%%',explode = (0, 0.1), startangle=90,
                colors=survived_palette
                 )

# Survived
notsurvived = train[train['Survived']==0]['Sex'].value_counts()[['male', 'female']]
ax_pie_notsurvived.pie(notsurvived, labels=notsurvived.index, autopct='%1.1f%%',startangle=90,
                      colors=sex_palette, textprops={'color':"w"}
                      )

survived = train[train['Survived']==1]['Sex'].value_counts()[['male', 'female']]
ax_pie_survived.pie(survived, labels=survived.index, autopct='%1.1f%%', startangle=90,
                    colors=sex_palette, textprops={'color':"w"}
                   )

fig.suptitle('[Sex & Survived] Conditional Distribution', fontweight='bold', fontsize=20)
fig.text(s='''Gender and survival are the most important features of the existing Titanic problem.\nLook at each conditional probability and think of the minimum score''', 
         x=0.5, y= 0.94, ha='center', va='top')

plt.show()

# %%
def age_band(num):
    for i in range(1, 100):
        if num < 10*i : return f'{(i-1) * 10} ~ {i*10}'
        
        
train['Age band'] = train['Age'].apply(age_band)
titanic_age = train[['Age band', 'Survived']].groupby('Age band')['Survived'].value_counts().sort_index().unstack()
titanic_age['Survival rate'] = titanic_age[1] / (titanic_age[0] + titanic_age[1]) * 100
age_band = train['Age band'].value_counts().sort_index()
print(age_band)
# Out:
# 0 ~ 10      8611
# 10 ~ 20     4999
# 20 ~ 30    20283
# 30 ~ 40    15783
# 40 ~ 50    15677
# 50 ~ 60    18134
# 60 ~ 70    10819
# 70 ~ 80     2318
# 80 ~ 90       84
# Name: Age band, dtype: int64

# %%
pip install --upgrade matplotlib
# Out:
# Requirement already up-to-date: matplotlib in /usr/local/lib/python3.7/dist-packages (3.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.19.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (7.1.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

fig = plt.figure(figsize=(15, 10))
gs = fig.add_gridspec(3, 4)
ax = fig.add_subplot(gs[:-1,:])

color_map = ['#d4dddd' for _ in range(9)]
color_map[2] = light_palette[3]
color_map[8] = light_palette[2]


bars = ax.bar(titanic_age['Survival rate'].index, titanic_age['Survival rate'], 
       color=color_map, width=0.55, 
       edgecolor='black', 
       linewidth=0.7)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.bar_label(bars, fmt='%.2f%%')


# mean line + annotation
mean = train['Survived'].mean() *100
ax.axhline(mean ,color='black', linewidth=0.4, linestyle='dashdot')
ax.annotate(f"mean : {mean :.4}%", 
            xy=('20 ~ 30', mean + 4),
            va = 'center', ha='center',
            color='#4a4a4a',
            bbox=dict(boxstyle='round', pad=0.4, facecolor='#efe8d1', linewidth=0))
    


ax.set_yticks(np.arange(0, 81, 20))
ax.grid(axis='y', linestyle='-', alpha=0.4)
ax.set_ylim(0, 85)


ax_bottom = fig.add_subplot(gs[-1,:])
bars = ax_bottom.bar(age_band.index, age_band, width=0.55, 
       edgecolor='black', 
       linewidth=0.7)

ax_bottom.spines[["top","right","left"]].set_visible(False)
ax_bottom.bar_label(bars, fmt='%d', label_type='center', color='white')
ax_bottom.grid(axis='y', linestyle='-', alpha=0.4)

# Title & Subtitle    
fig.text(0.1, 1, 'Age Band & Survival Rate', fontsize=15, fontweight='bold', fontfamily='serif', ha='left')
fig.text(0.1, 0.96, 'Unlike before, the survival rate of infants and toddlers is very low.', fontsize=12, fontweight='light', fontfamily='serif', ha='left')

plt.show()

# %%
def get_category_fare_age(fare_age):
    cat = ''
    if fare_age <= -1: cat = 'Unknown'
    elif fare_age <= 5000: cat = 'Low'
    elif fare_age <= 10000: cat = 'Middle '
    elif fare_age <= 20000: cat = 'High'
    elif fare_age <= 40000: cat = 'Very High'
    else : cat = 'Ultra High'
    
    return cat

# %%
train['Age'].fillna(train['Age'].mean(), inplace=True)
train['Fare'].fillna(train['Fare'].mean(), inplace=True)

train['Fare*Age'] = train['Age'] * train['Fare']
train['Fare*Age'] = train['Fare*Age'].apply(lambda x : get_category_fare_age(x))
titanic_fare_age = train[['Fare*Age', 'Survived']].groupby('Fare*Age')['Survived'].value_counts().sort_index().unstack()
titanic_fare_age['Survival rate'] = titanic_fare_age[1] / (titanic_fare_age[0] + titanic_fare_age[1]) * 100

Fare_Age = train['Fare*Age'].value_counts().sort_index()

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

fig = plt.figure(figsize=(15, 10))
gs = fig.add_gridspec(3, 4)
ax = fig.add_subplot(gs[:-1,:])

color_map = ['#d4dddd' for _ in range(5)]
color_map[1] = light_palette[3]
color_map[3] = light_palette[2]


bars = ax.bar(titanic_fare_age['Survival rate'].index, titanic_fare_age['Survival rate'], 
       color=color_map, width=0.55, 
       edgecolor='black', 
       linewidth=0.7)

ax.spines[["top","right","left"]].set_visible(False)
ax.bar_label(bars, fmt='%.2f%%')


# mean line + annotation
mean = train['Survived'].mean() *100
ax.axhline(mean ,color='black', linewidth=0.4, linestyle='dashdot')
ax.annotate(f"mean : {mean :.4}%", 
            xy=('Low', mean + 4),
            va = 'center', ha='center',
            color='#4a4a4a',
            bbox=dict(boxstyle='round', pad=0.4, facecolor='#efe8d1', linewidth=0))
    



ax.set_yticks(np.arange(0, 100, 20))
ax.grid(axis='y', linestyle='-', alpha=0.4)
ax.set_ylim(0, 100)


ax_bottom = fig.add_subplot(gs[-1,:])
bars = ax_bottom.bar(Fare_Age.index, Fare_Age, width=0.55, 
       edgecolor='black', 
       linewidth=0.7)

ax_bottom.spines[["top","right","left"]].set_visible(False)
ax_bottom.bar_label(bars, fmt='%d', label_type='center', color='white')
ax_bottom.grid(axis='y', linestyle='-', alpha=0.4)

# Title & Subtitle    
fig.text(0.1, 1, 'Fare x Age & Survival Rate', fontsize=15, fontweight='bold', fontfamily='serif', ha='left')
fig.text(0.1, 0.96, 'the survival rate of Low is very low.', fontsize=12, fontweight='light', fontfamily='serif', ha='left')

plt.show()

# %%
num_columns = ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
def show_hist_by_target(df, columns):
    cond_1 = (df['Survived'] == 1)
    cond_0 = (df['Survived'] == 0)

    for column in columns:
        fig, axs = plt.subplots(figsize=(12, 4), nrows=1, ncols=2, squeeze=False)
        sns.violinplot(x='Survived', y=column, data=df, ax=axs[0][0])
        sns.distplot(df[cond_1][column], label='1', color='red', ax=axs[0][1])
        sns.distplot(df[cond_0][column], label='0', color='blue', ax=axs[0][1])

# %%
show_hist_by_target(train, num_columns)

# %%
def get_category_age(age):
    cat = ''
    if age <= -1: cat = 'Unknown'
    elif age <= 5: cat = 'Baby'
    elif age <= 12: cat = 'Child'
    elif age <= 18: cat = 'Teenager'
    elif age <= 25: cat = 'Student'
    elif age <= 35: cat = 'Young Adult'
    elif age <= 60: cat = 'Adult'
    else : cat = 'Elderly'
    
    return cat

# %%
train['Age'].fillna(train['Age'].mean(), inplace=True)
train['Age'] = train['Age'].apply(lambda x : get_category_age(x))

# %%
def get_category_fare(fare):
    cat = ''
    if fare <= -1: cat = 'Unknown'
    elif fare <= 40: cat = 'Lower Class'
    elif fare < 150: cat = 'Middle Class'
    elif fare <= 300: cat = 'Upper Middle Class'
    elif fare <= 400: cat = 'Upper Class'
    elif fare <= 600: cat = 'Rich'
    elif fare <= 800: cat = 'Super Rich'
    else : cat = 'Crazy Rich'
    
    return cat

# %% [markdown]
# 1등실 : (응접실이 딸린 스위트 룸) $4,350
#
# 1등실 : (침실칸) $150
#
# 2등실 : 60$
#
# 3등실 : 15~40$

# %%
train['Fare'].fillna(train['Fare'].mean(), inplace=True)
train['Fare'] = train['Fare'].apply(lambda x : get_category_fare(x))

# %%
def get_category_name(name):
    cat = ''
    if name <= -1: cat = 'Unknown'
    elif name <= 2: cat = 'highly rare'
    elif name <= 5: cat = 'rare'
    elif name <= 50: cat = 'slightly common'
    elif name <= 500: cat = 'common'
    elif name <= 1000: cat = 'moderately common'
    else : cat = 'highly common'
    
    return cat

# %%
train['FamName'] = train['Name'].str.extract('([A-Za-z]+)\,', expand=False)
FamName = train['FamName'].value_counts()
FamName = FamName.apply(lambda x : get_category_name(x))
train['FamName'] = train['FamName'].apply(lambda x: FamName[x])
print(train['FamName'].value_counts())
# Out:
# slightly common      33623
# common               25255
# highly rare          19463
# rare                 16949
# moderately common     3548
# highly common         1162
# Name: FamName, dtype: int64

# %%
def get_category_family(family):
    cat = ''
    if family <= -1: cat = 'Unknown'
    elif family <= 1: cat = 'Alone'
    elif family <= 2: cat = 'Couple'
    elif family <= 5: cat = 'Small'
    elif family <= 8: cat = 'Medium'
    elif family <= 12: cat = 'Big'
    else : cat = 'Very Big'
    
    return cat

# %%
train['FamSize'] = train['SibSp'] + train['Parch'] + 1
train['FamSize'] = train['FamSize'].apply(lambda x : get_category_family(x))

# %%
train['Ticket'] = train['Ticket'].apply(lambda x: x[0] if type(x) == str else 'Missing')

# %%
train['Cabin'] = train['Cabin'].apply(lambda x: x[0] if type(x) == str else 'Missing')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PassengerId  100000 non-null  int64
#  1   Survived     100000 non-null  int64
#  2   Pclass       100000 non-null  int64
#  3   Name         100000 non-null  object
#  4   Sex          100000 non-null  object
#  5   Age          100000 non-null  object
#  6   SibSp        100000 non-null  int64
#  7   Parch        100000 non-null  int64
#  8   Ticket       100000 non-null  object
#  9   Fare         100000 non-null  object
#  10  Cabin        100000 non-null  object
#  11  Embarked     99750 non-null   object
#  12  Age band     96708 non-null   object
#  13  Fare*Age     100000 non-null  object
#  14  FamName      100000 non-null  object
#  15  FamSize      100000 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 12.2+ MB

# %%
train.dtypes[train.dtypes == 'object'].index.tolist()
# Out:
# ['Name',
#  'Sex',
#  'Age',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'Age band',
#  'Fare*Age',
#  'FamName',
#  'FamSize']

# %%
object_columns = ['Age','FamName','FamSize','Cabin','Ticket','Fare']

# %%
def show_category_by_target(df,columns):
    for column in columns:
        print('column name:',column)
        chart = sns.catplot(x=column, col='Survived', data=df, kind='count')
        chart.set_xticklabels(rotation=65)

show_category_by_target(train, object_columns)
# Out:
# column name: Age
# column name: FamName
# column name: FamSize
# column name: Cabin
# column name: Ticket
# column name: Fare

# %%
train = pd.read_csv('./train.csv')
test= pd.read_csv('./test.csv')
sample_submission = pd.read_csv('./sample_submission.csv')

train.shape, test.shape, sample_submission.shape
# Out:
# ((100000, 12), (100000, 11), (100000, 2))

# %%
print(train['Embarked'].value_counts())
# Out:
# S    72139
# C    22187
# Q     5424
# Name: Embarked, dtype: int64

# %%
Survived_0 = (train['Survived'] == 0)
Survived_1 = (train['Survived'] == 1)

# Embarked에 따른 사망 비율
print('_'*20)
print('Embarked에 따른 사망 비율') 
print('S :',train[Survived_0 & (train['Embarked'] == 'S')]['Embarked'].count() / train[Survived_0].shape[0])
print('C :',train[Survived_0 & (train['Embarked'] == 'C')]['Embarked'].count() / train[Survived_0].shape[0])
print('Q :',train[Survived_0 & (train['Embarked'] == 'Q')]['Embarked'].count() / train[Survived_0].shape[0])

# Embarked에 따른 사망 비율
print('_'*20)
print('Embarked에 따른 생존 비율') 
print('S :',train[Survived_0 & (train['Embarked'] == 'S')]['Embarked'].count() / train[Survived_0].shape[0])
print('C :',train[Survived_0 & (train['Embarked'] == 'C')]['Embarked'].count() / train[Survived_0].shape[0])
print('Q :',train[Survived_0 & (train['Embarked'] == 'Q')]['Embarked'].count() / train[Survived_0].shape[0])


# S : 사망 비율 / 생존 비율
print('_'*20)
print('S : 사망 비율 / 생존 비율')
print('사망 비율 : ',train[Survived_0 & (train['Embarked'] == 'S')]['Embarked'].count() / train[train['Embarked'] == 'S'].shape[0])
print('생존 비율 : ',train[Survived_1 & (train['Embarked'] == 'S')]['Embarked'].count() / train[train['Embarked'] == 'S'].shape[0])

# C : 사망 비율 / 생존 비율
print('_'*20)
print('C : 사망 비율 / 생존 비율')
print('사망 비율 : ',train[Survived_0 & (train['Embarked'] == 'C')]['Embarked'].count() / train[train['Embarked'] == 'C'].shape[0])
print('생존 비율 : ',train[Survived_1 & (train['Embarked'] == 'C')]['Embarked'].count() / train[train['Embarked'] == 'C'].shape[0])

# Q : 사망 비율 / 생존 비율
print('_'*20)
print(' Q : 사망 비율 / 생존 비율')
print('사망 비율 : ',train[Survived_0 & (train['Embarked'] == 'Q')]['Embarked'].count() / train[train['Embarked'] == 'Q'].shape[0])
print('생존 비율 : ',train[Survived_1 & (train['Embarked'] == 'Q')]['Embarked'].count() / train[train['Embarked'] == 'Q'].shape[0])
# Out:
# ____________________
# Embarked에 따른 사망 비율
# S : 0.8631391325621222
# C : 0.09642470205850487
# Q : 0.038199419844126795
# ____________________
# Embarked에 따른 생존 비율
# S : 0.8631391325621222
# C : 0.09642470205850487
# Q : 0.038199419844126795
# ____________________
# S : 사망 비율 / 생존 비율
# 사망 비율 :  0.6847059149697112
# 생존 비율 :  0.3152940850302888
# ____________________
# C : 사망 비율 / 생존 비율
# 사망 비율 :  0.24870419615089917
# 생존 비율 :  0.7512958038491008
# ____________________
#  Q : 사망 비율 / 생존 비율
# 사망 비율 :  0.403023598820059
# 생존 비율 :  0.596976401179941

# %%
# Embarked가 S일 경우 Fare의 평균값
print(train[train['Embarked'] == 'S']['Fare'].mean())
# Embarked가 C일 경우 Fare의 평균값 
print(train[train['Embarked'] == 'C']['Fare'].mean())
# Embarked가 Q일 경우 Fare의 평균값
print(train[train['Embarked'] == 'Q']['Fare'].mean())
# Out:
# 33.20000777270393
# 71.54907285366082
# 73.38514771048735

# %% [markdown]
# Southampton에서 승선한 승객들이 대체로 탑승 요금이 적다는 부분에서 이들의 대부분이 3등실에 탔을 것이라고 예측할 수 있다.

# %%
titanic_embarked = train[['Embarked', 'Survived']].groupby('Embarked')['Survived'].value_counts().sort_index().unstack()
titanic_embarked['Survival rate'] = titanic_embarked[1] / (titanic_embarked[0] + titanic_embarked[1]) * 100

embarked = train['Embarked'].value_counts().sort_index()

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

fig = plt.figure(figsize=(15, 10))
gs = fig.add_gridspec(3, 4)
ax = fig.add_subplot(gs[:-1,:])

color_map = ['#d4dddd' for _ in range(3)]
color_map[2] = light_palette[2]


bars = ax.bar(titanic_embarked['Survival rate'].index, titanic_embarked['Survival rate'], 
       color=color_map, width=0.55, 
       edgecolor='black', 
       linewidth=0.7)

ax.spines[["top","right","left"]].set_visible(False)
ax.bar_label(bars, fmt='%.2f%%')


# mean line + annotation
mean = train['Survived'].mean() *100
ax.axhline(mean ,color='black', linewidth=0.4, linestyle='dashdot')
ax.annotate(f"mean : {mean :.4}%", 
            xy=('S', mean + 4),
            va = 'center', ha='center',
            color='#4a4a4a',
            bbox=dict(boxstyle='round', pad=0.4, facecolor='#efe8d1', linewidth=0))
    



ax.set_yticks(np.arange(0, 100, 20))
ax.grid(axis='y', linestyle='-', alpha=0.4)
ax.set_ylim(0, 100)


ax_bottom = fig.add_subplot(gs[-1,:])
bars = ax_bottom.bar(embarked.index, embarked, width=0.55, 
       edgecolor='black', 
       linewidth=0.7)

ax_bottom.spines[["top","right","left"]].set_visible(False)
ax_bottom.bar_label(bars, fmt='%d', label_type='center', color='white')
ax_bottom.grid(axis='y', linestyle='-', alpha=0.4)

# Title & Subtitle    
fig.text(0.1, 1, 'Embarked & Survival Rate', fontsize=15, fontweight='bold', fontfamily='serif', ha='left')
fig.text(0.1, 0.96, 'the survival rate of Southamton is very low.', fontsize=12, fontweight='light', fontfamily='serif', ha='left')

plt.show()

# %% [markdown]
# <a id='handling_missing_values'></a>
# ### (3) Handling Missing Values
# - Let's fill with some value in each column.
# > *Important Note:* This idea is from [TPS Apr 2021 LightGBM CV](https://www.kaggle.com/jmargni/tps-apr-2021-lightgbm-cv). Thank you.

# %%
temp = pd.concat([train, test])

# %%
temp['Fare'] = temp['Fare'].fillna(temp['Fare'].mean())
temp['Age'] = temp['Age'].fillna(temp['Age'].mean())
temp['Embarked'] = temp['Embarked'].fillna('N')
temp['Cabin'] = temp['Cabin'].str[:1]
temp['FirstName'] = temp['Name'].apply(lambda x:x.split(', ')[0])
temp['n'] = 1
gb = temp.groupby('FirstName')
df_names = gb['n'].sum()
temp['SameFirstName'] = temp['FirstName'].apply(lambda x:df_names[x])
temp['SameFirstName'] = temp['SameFirstName'].apply(lambda x:-1 if x>10 else x)
temp = temp.drop(['n','FirstName'],axis=1)

temp['Name'] = temp['Name'].map(lambda x: str(x).split(',')[0])
temp['Ticket'] = temp['Ticket'].map(lambda x:str(x).split()[0] if len(str(x).split()) > 1 else 'X')
temp['Cabin'] = temp['Cabin'].map(lambda x: str(x)[0].strip())

temp['Family_Size'] = temp['SibSp'] + temp['Parch'] + 1
temp['Alone?'] = False
temp.loc[temp['Family_Size'] == 1, 'Alone?'] = True
temp['Cabin?'] = temp['Cabin'].apply(lambda x: False if str(x[:1]) == 'n' else True)
temp['Age*Fare'] = temp['Age'] * temp['Fare']
temp['Age/Fare'] = temp['Age'] / temp['Fare']

# %%
temp.tail(5)
# Out:
#        PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 99995       199995       NaN       3       Cash  female  27.0      0      0
# 99996       199996       NaN       1      Brown    male  59.0      1      0
# 99997       199997       NaN       3  Lightfoot    male  47.0      0      0
# 99998       199998       NaN       1   Jacobsen  female  49.0      1      2
# 99999       199999       NaN       1   Fishback  female  41.0      0      2
#
#       Ticket    Fare Cabin Embarked  SameFirstName  Family_Size  Alone?  \
# 99995      X   10.12     n        Q             -1            1    True
# 99996      X   68.31     n        S             -1            2   False
# 99997      X   10.87     n        S              8            1    True
# 99998     PC   29.68     B        C             -1            4   False
# 99999     PC  195.41     E        C              3            3   False
#
#        Cabin?  Age*Fare  Age/Fare
# 99995   False    273.24  2.667984
# 99996   False   4030.29  0.863710
# 99997   False    510.89  4.323827
# 99998    True   1454.32  1.650943
# 99999    True   8011.81  0.209815

# %%
temp.select_dtypes(exclude=['float64','int64','bool']).columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch', 'Ticket',
#        'Cabin', 'Embarked', 'SameFirstName', 'Family_Size'],
#       dtype='object')

# %%
np.where((temp.dtypes != 'float64')&(temp.dtypes != 'int64')&(temp.dtypes != 'bool'))[0].tolist()
# Out:
# [3, 4, 8, 10, 11]

# %%
categorical_feature = np.where((temp.dtypes != 'float64')&(temp.dtypes != 'int64')&(temp.dtypes != 'bool'))[0].tolist()
categorical_feature_columns = temp.select_dtypes(exclude=['float64','int64','bool']).columns

# %% [markdown]
# <a id='feature_encoding'></a>
# ### (4) Feature Encoding
# - Let's check each column's data type

# %% [markdown]
# - Dataset will be divided into two groups - categorical variables and numerical variables

# %%
label = LabelEncoder()
for column in categorical_feature_columns:
    label.fit(temp[column])
    temp[column] = label.transform(temp[column])

# %% [markdown]
# > Important note: When conducting feature encoding, Newbies must understand difference between ordinal encoding, label encoding, and one-hot encoding. See. https://machinelearningmastery.com/one-hot-encoding-for-categorical-data/

# %% [markdown]
# <a id='split_data'></a>
# ### (5) Split Data
# - Based on Feature Engineering, the final task is to re-split all data into independent variables and dependent variables.

# %%
train_df = temp[:100000]
test_df = temp[100000:]
train_df.shape, test_df.shape
# Out:
# ((100000, 18), (100000, 18))

# %%
test_df = test_df.drop(['Survived'],axis=1)
X = train_df.drop(['Survived'],axis=1)
y = train_df['Survived']

# %%
X.shape, y.shape
# Out:
# ((100000, 17), (100000,))

# %% [markdown]
# <a id="limitation"></a>
# ### (6) Limitation
# - What I missed here is not to create new variable so-called wealthy class and others, yet. My assumption is wealthy people were more survived than other group. This will be compared baseline model with the more upgraded model, reflecting new feature. If some readers get this idea, then please implement it. Hope to see a better model.

# %% [markdown]
# <a id="scikit_learn"></a>
# ## Scikit Learn
# - Let's make simple model based on Scikit Learn Framework.
# - URL: https://scikit-learn.org/stable/
#
# ![](https://scikit-learn.org/stable/_images/scikit-learn-logo-notext.png)

# %% [markdown]
# <a id="data_split"></a>
# ### (1) Data Split
# - We know test data exists as final testset, so we create validation set from sklearn module.
# - We will use [Stratified Sampling](https://medium.com/@411.codebrain/train-test-split-vs-stratifiedshufflesplit-374c3dbdcc36).

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.2.post1

# %%
# !pip install bayesian-optimization==1.1.0
# Out:
# Requirement already satisfied: bayesian-optimization==1.1.0 in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization==1.1.0) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization==1.1.0) (1.19.5)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization==1.1.0) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization==1.1.0) (1.0.1)

# %%
from bayes_opt import BayesianOptimization

# %%
bayes_x,bayes_x_test,bayes_y,bayes_y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
bayes_params = {
    'num_leaves': (24, 45),
    'colsample_bytree':(0.5, 1), 
    'subsample': (0.5, 1),
    'max_depth': (4, 12),
    'reg_alpha': (0, 0.5),
    'reg_lambda': (0, 0.5), 
    'min_split_gain': (0.001, 0.1),
    'min_child_weight':(5, 50)
}

# %%
def lgb_roc_eval(num_leaves, colsample_bytree, subsample, max_depth, reg_alpha, reg_lambda, min_split_gain, min_child_weight):
    
    params = {
        "n_estimator":200, "learning_rate":0.02,
        'num_leaves': int(round(num_leaves)),   #  호출 시 실수형 값이 들어오므로 정수형 하이퍼 파라미터는 정수형으로 변경 
        'colsample_bytree': colsample_bytree, 
        'subsample': subsample,
        'max_depth': int(round(max_depth)),
        'reg_alpha': reg_alpha,
        'reg_lambda': reg_lambda, 
        'min_split_gain': min_split_gain,
        'min_child_weight': min_child_weight
    }
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(bayes_x, bayes_y, eval_set=[(bayes_x_test, bayes_y_test)], early_stopping_rounds=30, eval_metric="auc", verbose=100 )
    valid_proba = lgb_model.predict_proba(bayes_x_test, num_iteration=10)[:,1]
    roc_preds = roc_auc_score(bayes_y_test, valid_proba)
    
    return roc_preds

# %%
BO_lgb = BayesianOptimization(lgb_roc_eval, bayes_params, random_state=2121)

# %%
BO_lgb.maximize(init_points=5, n_iter=10)


BO_lgb.max
# Out:
# |   iter    |  target   | colsam... | max_depth | min_ch... | min_sp... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.849304	valid_0's binary_logloss: 0.491038
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.849304	valid_0's binary_logloss: 0.491038
# |  1        |  0.8455   |  0.6272   |  11.85    |  41.96    |  0.09067  |  37.01    |  0.2805   |  0.1433   |  0.9287   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.849533	valid_0's binary_logloss: 0.4894
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.849533	valid_0's binary_logloss: 0.4894
# |  2        |  0.8469   |  0.6589   |  11.49    |  31.42    |  0.006496 |  40.42    |  0.4495   |  0.2151   |  0.7366   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.843513	valid_0's binary_logloss: 0.492507
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.843513	valid_0's binary_logloss: 0.492507
# |  3        |  0.8397   |  0.9127   |  4.011    |  35.96    |  0.02572  |  29.34    |  0.1736   |  0.3874   |  0.7569   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.848458	valid_0's binary_logloss: 0.486517
# Did not meet early stopping. Best iteration is:
# [97]	valid_0's auc: 0.848464	valid_0's binary_logloss: 0.487474
# |  4        |  0.8444   |  0.8258   |  7.003    |  7.741    |  0.0727   |  34.27    |  0.1116   |  0.09012  |  0.5757   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.847302	valid_0's binary_logloss: 0.493792
# Did not meet early stopping. Best iteration is:
# [98]	valid_0's auc: 0.847304	valid_0's binary_logloss: 0.494454
# |  5        |  0.8437   |  0.6325   |  4.501    |  26.91    |  0.0196   |  31.3     |  0.4319   |  0.1156   |  0.6588   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.845138	valid_0's binary_logloss: 0.495713
# Did not meet early stopping. Best iteration is:
# [96]	valid_0's auc: 0.845161	valid_0's binary_logloss: 0.497411
# |  6        |  0.8419   |  0.6885   |  4.352    |  7.151    |  0.0932   |  44.7     |  0.3253   |  0.468    |  0.9995   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.848696	valid_0's binary_logloss: 0.492109
# Did not meet early stopping. Best iteration is:
# [98]	valid_0's auc: 0.848705	valid_0's binary_logloss: 0.492768
# |  7        |  0.8448   |  0.6436   |  11.97    |  5.95     |  0.09788  |  26.47    |  0.4139   |  0.2401   |  0.645    |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.849676	valid_0's binary_logloss: 0.490505
# Did not meet early stopping. Best iteration is:
# [98]	valid_0's auc: 0.849678	valid_0's binary_logloss: 0.49118
# |  8        |  0.846    |  0.6012   |  11.91    |  5.06     |  0.0356   |  44.58    |  0.07844  |  0.435    |  0.9903   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.849455	valid_0's binary_logloss: 0.486107
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.849455	valid_0's binary_logloss: 0.486107
# |  9        |  0.8469   |  0.7957   |  11.9     |  47.21    |  0.03234  |  44.19    |  0.009659 |  0.3508   |  0.6      |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.849424	valid_0's binary_logloss: 0.48621
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.849424	valid_0's binary_logloss: 0.48621
# |  10       |  0.847    |  0.7803   |  11.95    |  47.96    |  0.02974  |  44.84    |  0.3153   |  0.4019   |  0.5366   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.849295	valid_0's binary_logloss: 0.492414
# Did not meet early stopping. Best iteration is:
# [98]	valid_0's auc: 0.849307	valid_0's binary_logloss: 0.493111
# |  11       |  0.8462   |  0.573    |  11.98    |  48.55    |  0.08484  |  44.03    |  0.3425   |  0.3919   |  0.5156   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.849693	valid_0's binary_logloss: 0.48766
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.849693	valid_0's binary_logloss: 0.48766
# |  12       |  0.8471   |  0.7138   |  11.53    |  5.807    |  0.0797   |  44.7     |  0.1802   |  0.4283   |  0.842    |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.849756	valid_0's binary_logloss: 0.487588
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.849756	valid_0's binary_logloss: 0.487588
# |  13       |  0.8472   |  0.7594   |  11.83    |  9.425    |  0.03123  |  44.95    |  0.2724   |  0.1769   |  0.5328   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.84962	valid_0's binary_logloss: 0.489249
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.84962	valid_0's binary_logloss: 0.489249
# |  14       |  0.8472   |  0.6746   |  11.82    |  5.217    |  0.07315  |  44.5     |  0.3218   |  0.4902   |  0.5596   |
# Training until validation scores don't improve for 30 rounds.
# [100]	valid_0's auc: 0.848384	valid_0's binary_logloss: 0.484866
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.848384	valid_0's binary_logloss: 0.484866
# |  15       |  0.8452   |  0.963    |  11.98    |  9.275    |  0.04005  |  44.83    |  0.1806   |  0.4267   |  0.7633   |
# =========================================================================================================================
# {'params': {'colsample_bytree': 0.7593967276132256,
#   'max_depth': 11.8347960713356,
#   'min_child_weight': 9.424762717827463,
#   'min_split_gain': 0.031227555921758205,
#   'num_leaves': 44.94986099209425,
#   'reg_alpha': 0.2723737868933406,
#   'reg_lambda': 0.17688702915632337,
#   'subsample': 0.5327739383621304},
#  'target': 0.847189885122777}

# %%
lgbm_parameters = {'colsample_bytree': 0.7280751661082743,
  'max_depth': 8,
  'min_child_weight': 5.845541019635982,
  'min_split_gain': 0.062145914210511834,
  'num_leaves': 37,
  'reg_alpha': 0.30846699843737846,
  'reg_lambda': 0.4718740392573121,
  'subsample': 0.8409101495517417
  }

# %%
lgbm_parameters['objective'] = 'binary'
lgbm_parameters['n_estimators'] = 15000

# %%
lgbm_test_pred = np.zeros(len(test))
n_splits = 10

skfold = StratifiedKFold(n_splits=n_splits, shuffle=True)

lgbm_acc=[]
lgbm_auc=[]

for train_index, valid_index in skfold.split(X, y):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

    lgbm_wrapper = LGBMClassifier(**lgbm_parameters)

    evals = [(X_valid, y_valid)]
    lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric="binary_logloss", 
                    eval_set=evals, verbose=True)


    lgbm_test_pred += lgbm_wrapper.predict_proba(test_df)[:,1]/n_splits
    lgbm_auc.append(roc_auc_score(y_valid, lgbm_wrapper.predict_proba(X_valid)[:,1]))
    lgbm_acc.append(accuracy_score(y_valid, (lgbm_wrapper.predict_proba(X_valid)[:,1] > 0.5).astype(int)))

print(f'AUC: {np.mean(lgbm_auc)}')
print(f'ACC: {np.mean(lgbm_acc)}')
# Out:
# [1]	valid_0's binary_logloss: 0.648684	valid_0's binary_logloss: 0.648684
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.620125	valid_0's binary_logloss: 0.620125
# [3]	valid_0's binary_logloss: 0.596867	valid_0's binary_logloss: 0.596867
# [4]	valid_0's binary_logloss: 0.578487	valid_0's binary_logloss: 0.578487
# [5]	valid_0's binary_logloss: 0.562071	valid_0's binary_logloss: 0.562071
# [6]	valid_0's binary_logloss: 0.555636	valid_0's binary_logloss: 0.555636
# [7]	valid_0's binary_logloss: 0.547151	valid_0's binary_logloss: 0.547151
# [8]	valid_0's binary_logloss: 0.535586	valid_0's binary_logloss: 0.535586
# [9]	valid_0's binary_logloss: 0.526074	valid_0's binary_logloss: 0.526074
# [10]	valid_0's binary_logloss: 0.518344	valid_0's binary_logloss: 0.518344
# [11]	valid_0's binary_logloss: 0.511847	valid_0's binary_logloss: 0.511847
# [12]	valid_0's binary_logloss: 0.505908	valid_0's binary_logloss: 0.505908
# [13]	valid_0's binary_logloss: 0.50343	valid_0's binary_logloss: 0.50343
# [14]	valid_0's binary_logloss: 0.498949	valid_0's binary_logloss: 0.498949
# [15]	valid_0's binary_logloss: 0.495212	valid_0's binary_logloss: 0.495212
# [16]	valid_0's binary_logloss: 0.491988	valid_0's binary_logloss: 0.491988
# [17]	valid_0's binary_logloss: 0.489051	valid_0's binary_logloss: 0.489051
# [18]	valid_0's binary_logloss: 0.486516	valid_0's binary_logloss: 0.486516
# [19]	valid_0's binary_logloss: 0.484991	valid_0's binary_logloss: 0.484991
# [20]	valid_0's binary_logloss: 0.483791	valid_0's binary_logloss: 0.483791
# [21]	valid_0's binary_logloss: 0.482143	valid_0's binary_logloss: 0.482143
# [22]	valid_0's binary_logloss: 0.480539	valid_0's binary_logloss: 0.480539
# [23]	valid_0's binary_logloss: 0.479232	valid_0's binary_logloss: 0.479232
# [24]	valid_0's binary_logloss: 0.478443	valid_0's binary_logloss: 0.478443
# [25]	valid_0's binary_logloss: 0.477871	valid_0's binary_logloss: 0.477871
# [26]	valid_0's binary_logloss: 0.47698	valid_0's binary_logloss: 0.47698
# [27]	valid_0's binary_logloss: 0.476204	valid_0's binary_logloss: 0.476204
# [28]	valid_0's binary_logloss: 0.475459	valid_0's binary_logloss: 0.475459
# [29]	valid_0's binary_logloss: 0.474878	valid_0's binary_logloss: 0.474878
# [30]	valid_0's binary_logloss: 0.474364	valid_0's binary_logloss: 0.474364
# [31]	valid_0's binary_logloss: 0.473811	valid_0's binary_logloss: 0.473811
# [32]	valid_0's binary_logloss: 0.473462	valid_0's binary_logloss: 0.473462
# [33]	valid_0's binary_logloss: 0.473131	valid_0's binary_logloss: 0.473131
# [34]	valid_0's binary_logloss: 0.472845	valid_0's binary_logloss: 0.472845
# [35]	valid_0's binary_logloss: 0.472631	valid_0's binary_logloss: 0.472631
# [36]	valid_0's binary_logloss: 0.472361	valid_0's binary_logloss: 0.472361
# [37]	valid_0's binary_logloss: 0.472086	valid_0's binary_logloss: 0.472086
# [38]	valid_0's binary_logloss: 0.47193	valid_0's binary_logloss: 0.47193
# [39]	valid_0's binary_logloss: 0.471706	valid_0's binary_logloss: 0.471706
# [40]	valid_0's binary_logloss: 0.471536	valid_0's binary_logloss: 0.471536
# [41]	valid_0's binary_logloss: 0.471318	valid_0's binary_logloss: 0.471318
# [42]	valid_0's binary_logloss: 0.471325	valid_0's binary_logloss: 0.471325
# [43]	valid_0's binary_logloss: 0.471116	valid_0's binary_logloss: 0.471116
# [44]	valid_0's binary_logloss: 0.470956	valid_0's binary_logloss: 0.470956
# [45]	valid_0's binary_logloss: 0.47079	valid_0's binary_logloss: 0.47079
# [46]	valid_0's binary_logloss: 0.470813	valid_0's binary_logloss: 0.470813
# [47]	valid_0's binary_logloss: 0.470706	valid_0's binary_logloss: 0.470706
# [48]	valid_0's binary_logloss: 0.470661	valid_0's binary_logloss: 0.470661
# [49]	valid_0's binary_logloss: 0.470639	valid_0's binary_logloss: 0.470639
# [50]	valid_0's binary_logloss: 0.470642	valid_0's binary_logloss: 0.470642
# [51]	valid_0's binary_logloss: 0.470538	valid_0's binary_logloss: 0.470538
# [52]	valid_0's binary_logloss: 0.47056	valid_0's binary_logloss: 0.47056
# [53]	valid_0's binary_logloss: 0.470591	valid_0's binary_logloss: 0.470591
# [54]	valid_0's binary_logloss: 0.470572	valid_0's binary_logloss: 0.470572
# [55]	valid_0's binary_logloss: 0.470576	valid_0's binary_logloss: 0.470576
# [56]	valid_0's binary_logloss: 0.470509	valid_0's binary_logloss: 0.470509
# [57]	valid_0's binary_logloss: 0.470533	valid_0's binary_logloss: 0.470533
# [58]	valid_0's binary_logloss: 0.470488	valid_0's binary_logloss: 0.470488
# [59]	valid_0's binary_logloss: 0.470429	valid_0's binary_logloss: 0.470429
# [60]	valid_0's binary_logloss: 0.470447	valid_0's binary_logloss: 0.470447
# [61]	valid_0's binary_logloss: 0.470471	valid_0's binary_logloss: 0.470471
# [62]	valid_0's binary_logloss: 0.470478	valid_0's binary_logloss: 0.470478
# [63]	valid_0's binary_logloss: 0.470425	valid_0's binary_logloss: 0.470425
# [64]	valid_0's binary_logloss: 0.47043	valid_0's binary_logloss: 0.47043
# [65]	valid_0's binary_logloss: 0.470437	valid_0's binary_logloss: 0.470437
# [66]	valid_0's binary_logloss: 0.470422	valid_0's binary_logloss: 0.470422
# [67]	valid_0's binary_logloss: 0.470333	valid_0's binary_logloss: 0.470333
# [68]	valid_0's binary_logloss: 0.47028	valid_0's binary_logloss: 0.47028
# [69]	valid_0's binary_logloss: 0.470301	valid_0's binary_logloss: 0.470301
# [70]	valid_0's binary_logloss: 0.470305	valid_0's binary_logloss: 0.470305
# [71]	valid_0's binary_logloss: 0.470334	valid_0's binary_logloss: 0.470334
# [72]	valid_0's binary_logloss: 0.470371	valid_0's binary_logloss: 0.470371
# [73]	valid_0's binary_logloss: 0.470334	valid_0's binary_logloss: 0.470334
# [74]	valid_0's binary_logloss: 0.470274	valid_0's binary_logloss: 0.470274
# [75]	valid_0's binary_logloss: 0.470356	valid_0's binary_logloss: 0.470356
# [76]	valid_0's binary_logloss: 0.470412	valid_0's binary_logloss: 0.470412
# [77]	valid_0's binary_logloss: 0.470434	valid_0's binary_logloss: 0.470434
# [78]	valid_0's binary_logloss: 0.470418	valid_0's binary_logloss: 0.470418
# [79]	valid_0's binary_logloss: 0.470468	valid_0's binary_logloss: 0.470468
# [80]	valid_0's binary_logloss: 0.470538	valid_0's binary_logloss: 0.470538
# [81]	valid_0's binary_logloss: 0.470617	valid_0's binary_logloss: 0.470617
# [82]	valid_0's binary_logloss: 0.470637	valid_0's binary_logloss: 0.470637
# [83]	valid_0's binary_logloss: 0.470655	valid_0's binary_logloss: 0.470655
# [84]	valid_0's binary_logloss: 0.470685	valid_0's binary_logloss: 0.470685
# [85]	valid_0's binary_logloss: 0.470668	valid_0's binary_logloss: 0.470668
# [86]	valid_0's binary_logloss: 0.470694	valid_0's binary_logloss: 0.470694
# [87]	valid_0's binary_logloss: 0.470675	valid_0's binary_logloss: 0.470675
# [88]	valid_0's binary_logloss: 0.4707	valid_0's binary_logloss: 0.4707
# [89]	valid_0's binary_logloss: 0.470725	valid_0's binary_logloss: 0.470725
# [90]	valid_0's binary_logloss: 0.470699	valid_0's binary_logloss: 0.470699
# [91]	valid_0's binary_logloss: 0.470745	valid_0's binary_logloss: 0.470745
# [92]	valid_0's binary_logloss: 0.470812	valid_0's binary_logloss: 0.470812
# [93]	valid_0's binary_logloss: 0.470854	valid_0's binary_logloss: 0.470854
# [94]	valid_0's binary_logloss: 0.470845	valid_0's binary_logloss: 0.470845
# [95]	valid_0's binary_logloss: 0.47087	valid_0's binary_logloss: 0.47087
# [96]	valid_0's binary_logloss: 0.470875	valid_0's binary_logloss: 0.470875
# [97]	valid_0's binary_logloss: 0.470953	valid_0's binary_logloss: 0.470953
# [98]	valid_0's binary_logloss: 0.470846	valid_0's binary_logloss: 0.470846
# [99]	valid_0's binary_logloss: 0.470836	valid_0's binary_logloss: 0.470836
# [100]	valid_0's binary_logloss: 0.470847	valid_0's binary_logloss: 0.470847
# [101]	valid_0's binary_logloss: 0.47087	valid_0's binary_logloss: 0.47087
# [102]	valid_0's binary_logloss: 0.470798	valid_0's binary_logloss: 0.470798
# [103]	valid_0's binary_logloss: 0.47086	valid_0's binary_logloss: 0.47086
# [104]	valid_0's binary_logloss: 0.470859	valid_0's binary_logloss: 0.470859
# [105]	valid_0's binary_logloss: 0.470842	valid_0's binary_logloss: 0.470842
# [106]	valid_0's binary_logloss: 0.470852	valid_0's binary_logloss: 0.470852
# [107]	valid_0's binary_logloss: 0.470821	valid_0's binary_logloss: 0.470821
# [108]	valid_0's binary_logloss: 0.47082	valid_0's binary_logloss: 0.47082
# [109]	valid_0's binary_logloss: 0.470815	valid_0's binary_logloss: 0.470815
# [110]	valid_0's binary_logloss: 0.470806	valid_0's binary_logloss: 0.470806
# [111]	valid_0's binary_logloss: 0.470747	valid_0's binary_logloss: 0.470747
# [112]	valid_0's binary_logloss: 0.470721	valid_0's binary_logloss: 0.470721
# [113]	valid_0's binary_logloss: 0.470737	valid_0's binary_logloss: 0.470737
# [114]	valid_0's binary_logloss: 0.470772	valid_0's binary_logloss: 0.470772
# [115]	valid_0's binary_logloss: 0.470852	valid_0's binary_logloss: 0.470852
# [116]	valid_0's binary_logloss: 0.470787	valid_0's binary_logloss: 0.470787
# [117]	valid_0's binary_logloss: 0.47077	valid_0's binary_logloss: 0.47077
# [118]	valid_0's binary_logloss: 0.470747	valid_0's binary_logloss: 0.470747
# [119]	valid_0's binary_logloss: 0.470715	valid_0's binary_logloss: 0.470715
# [120]	valid_0's binary_logloss: 0.47067	valid_0's binary_logloss: 0.47067
# [121]	valid_0's binary_logloss: 0.470681	valid_0's binary_logloss: 0.470681
# [122]	valid_0's binary_logloss: 0.470699	valid_0's binary_logloss: 0.470699
# [123]	valid_0's binary_logloss: 0.470678	valid_0's binary_logloss: 0.470678
# [124]	valid_0's binary_logloss: 0.470747	valid_0's binary_logloss: 0.470747
# [125]	valid_0's binary_logloss: 0.470784	valid_0's binary_logloss: 0.470784
# [126]	valid_0's binary_logloss: 0.470728	valid_0's binary_logloss: 0.470728
# [127]	valid_0's binary_logloss: 0.470732	valid_0's binary_logloss: 0.470732
# [128]	valid_0's binary_logloss: 0.470706	valid_0's binary_logloss: 0.470706
# [129]	valid_0's binary_logloss: 0.470675	valid_0's binary_logloss: 0.470675
# [130]	valid_0's binary_logloss: 0.470737	valid_0's binary_logloss: 0.470737
# [131]	valid_0's binary_logloss: 0.47076	valid_0's binary_logloss: 0.47076
# [132]	valid_0's binary_logloss: 0.470762	valid_0's binary_logloss: 0.470762
# [133]	valid_0's binary_logloss: 0.470679	valid_0's binary_logloss: 0.470679
# [134]	valid_0's binary_logloss: 0.47063	valid_0's binary_logloss: 0.47063
# [135]	valid_0's binary_logloss: 0.470683	valid_0's binary_logloss: 0.470683
# [136]	valid_0's binary_logloss: 0.470747	valid_0's binary_logloss: 0.470747
# [137]	valid_0's binary_logloss: 0.470723	valid_0's binary_logloss: 0.470723
# [138]	valid_0's binary_logloss: 0.470763	valid_0's binary_logloss: 0.470763
# [139]	valid_0's binary_logloss: 0.470792	valid_0's binary_logloss: 0.470792
# [140]	valid_0's binary_logloss: 0.470833	valid_0's binary_logloss: 0.470833
# [141]	valid_0's binary_logloss: 0.470891	valid_0's binary_logloss: 0.470891
# [142]	valid_0's binary_logloss: 0.470901	valid_0's binary_logloss: 0.470901
# [143]	valid_0's binary_logloss: 0.47093	valid_0's binary_logloss: 0.47093
# [144]	valid_0's binary_logloss: 0.470949	valid_0's binary_logloss: 0.470949
# [145]	valid_0's binary_logloss: 0.47095	valid_0's binary_logloss: 0.47095
# [146]	valid_0's binary_logloss: 0.47092	valid_0's binary_logloss: 0.47092
# [147]	valid_0's binary_logloss: 0.470946	valid_0's binary_logloss: 0.470946
# [148]	valid_0's binary_logloss: 0.470937	valid_0's binary_logloss: 0.470937
# [149]	valid_0's binary_logloss: 0.470924	valid_0's binary_logloss: 0.470924
# [150]	valid_0's binary_logloss: 0.470961	valid_0's binary_logloss: 0.470961
# [151]	valid_0's binary_logloss: 0.470975	valid_0's binary_logloss: 0.470975
# [152]	valid_0's binary_logloss: 0.47107	valid_0's binary_logloss: 0.47107
# [153]	valid_0's binary_logloss: 0.471111	valid_0's binary_logloss: 0.471111
# [154]	valid_0's binary_logloss: 0.471115	valid_0's binary_logloss: 0.471115
# [155]	valid_0's binary_logloss: 0.471159	valid_0's binary_logloss: 0.471159
# [156]	valid_0's binary_logloss: 0.471203	valid_0's binary_logloss: 0.471203
# [157]	valid_0's binary_logloss: 0.471266	valid_0's binary_logloss: 0.471266
# [158]	valid_0's binary_logloss: 0.471272	valid_0's binary_logloss: 0.471272
# [159]	valid_0's binary_logloss: 0.471316	valid_0's binary_logloss: 0.471316
# [160]	valid_0's binary_logloss: 0.47132	valid_0's binary_logloss: 0.47132
# [161]	valid_0's binary_logloss: 0.471401	valid_0's binary_logloss: 0.471401
# [162]	valid_0's binary_logloss: 0.471482	valid_0's binary_logloss: 0.471482
# [163]	valid_0's binary_logloss: 0.471539	valid_0's binary_logloss: 0.471539
# [164]	valid_0's binary_logloss: 0.471525	valid_0's binary_logloss: 0.471525
# [165]	valid_0's binary_logloss: 0.47156	valid_0's binary_logloss: 0.47156
# [166]	valid_0's binary_logloss: 0.471556	valid_0's binary_logloss: 0.471556
# [167]	valid_0's binary_logloss: 0.471503	valid_0's binary_logloss: 0.471503
# [168]	valid_0's binary_logloss: 0.471469	valid_0's binary_logloss: 0.471469
# [169]	valid_0's binary_logloss: 0.471369	valid_0's binary_logloss: 0.471369
# [170]	valid_0's binary_logloss: 0.471433	valid_0's binary_logloss: 0.471433
# [171]	valid_0's binary_logloss: 0.471362	valid_0's binary_logloss: 0.471362
# [172]	valid_0's binary_logloss: 0.471347	valid_0's binary_logloss: 0.471347
# [173]	valid_0's binary_logloss: 0.471341	valid_0's binary_logloss: 0.471341
# [174]	valid_0's binary_logloss: 0.471304	valid_0's binary_logloss: 0.471304
# Early stopping, best iteration is:
# [74]	valid_0's binary_logloss: 0.470274	valid_0's binary_logloss: 0.470274
# [1]	valid_0's binary_logloss: 0.649242	valid_0's binary_logloss: 0.649242
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.620879	valid_0's binary_logloss: 0.620879
# [3]	valid_0's binary_logloss: 0.597597	valid_0's binary_logloss: 0.597597
# [4]	valid_0's binary_logloss: 0.578882	valid_0's binary_logloss: 0.578882
# [5]	valid_0's binary_logloss: 0.562689	valid_0's binary_logloss: 0.562689
# [6]	valid_0's binary_logloss: 0.555858	valid_0's binary_logloss: 0.555858
# [7]	valid_0's binary_logloss: 0.547493	valid_0's binary_logloss: 0.547493
# [8]	valid_0's binary_logloss: 0.536254	valid_0's binary_logloss: 0.536254
# [9]	valid_0's binary_logloss: 0.526713	valid_0's binary_logloss: 0.526713
# [10]	valid_0's binary_logloss: 0.519005	valid_0's binary_logloss: 0.519005
# [11]	valid_0's binary_logloss: 0.512611	valid_0's binary_logloss: 0.512611
# [12]	valid_0's binary_logloss: 0.506597	valid_0's binary_logloss: 0.506597
# [13]	valid_0's binary_logloss: 0.503626	valid_0's binary_logloss: 0.503626
# [14]	valid_0's binary_logloss: 0.499211	valid_0's binary_logloss: 0.499211
# [15]	valid_0's binary_logloss: 0.495393	valid_0's binary_logloss: 0.495393
# [16]	valid_0's binary_logloss: 0.492309	valid_0's binary_logloss: 0.492309
# [17]	valid_0's binary_logloss: 0.489207	valid_0's binary_logloss: 0.489207
# [18]	valid_0's binary_logloss: 0.48685	valid_0's binary_logloss: 0.48685
# [19]	valid_0's binary_logloss: 0.485333	valid_0's binary_logloss: 0.485333
# [20]	valid_0's binary_logloss: 0.48406	valid_0's binary_logloss: 0.48406
# [21]	valid_0's binary_logloss: 0.482411	valid_0's binary_logloss: 0.482411
# [22]	valid_0's binary_logloss: 0.480772	valid_0's binary_logloss: 0.480772
# [23]	valid_0's binary_logloss: 0.479492	valid_0's binary_logloss: 0.479492
# [24]	valid_0's binary_logloss: 0.478706	valid_0's binary_logloss: 0.478706
# [25]	valid_0's binary_logloss: 0.478063	valid_0's binary_logloss: 0.478063
# [26]	valid_0's binary_logloss: 0.477217	valid_0's binary_logloss: 0.477217
# [27]	valid_0's binary_logloss: 0.476549	valid_0's binary_logloss: 0.476549
# [28]	valid_0's binary_logloss: 0.475858	valid_0's binary_logloss: 0.475858
# [29]	valid_0's binary_logloss: 0.475373	valid_0's binary_logloss: 0.475373
# [30]	valid_0's binary_logloss: 0.47488	valid_0's binary_logloss: 0.47488
# [31]	valid_0's binary_logloss: 0.474316	valid_0's binary_logloss: 0.474316
# [32]	valid_0's binary_logloss: 0.473832	valid_0's binary_logloss: 0.473832
# [33]	valid_0's binary_logloss: 0.473485	valid_0's binary_logloss: 0.473485
# [34]	valid_0's binary_logloss: 0.473318	valid_0's binary_logloss: 0.473318
# [35]	valid_0's binary_logloss: 0.473073	valid_0's binary_logloss: 0.473073
# [36]	valid_0's binary_logloss: 0.472867	valid_0's binary_logloss: 0.472867
# [37]	valid_0's binary_logloss: 0.472706	valid_0's binary_logloss: 0.472706
# [38]	valid_0's binary_logloss: 0.472511	valid_0's binary_logloss: 0.472511
# [39]	valid_0's binary_logloss: 0.472351	valid_0's binary_logloss: 0.472351
# [40]	valid_0's binary_logloss: 0.472252	valid_0's binary_logloss: 0.472252
# [41]	valid_0's binary_logloss: 0.472106	valid_0's binary_logloss: 0.472106
# [42]	valid_0's binary_logloss: 0.4721	valid_0's binary_logloss: 0.4721
# [43]	valid_0's binary_logloss: 0.47202	valid_0's binary_logloss: 0.47202
# [44]	valid_0's binary_logloss: 0.471909	valid_0's binary_logloss: 0.471909
# [45]	valid_0's binary_logloss: 0.471787	valid_0's binary_logloss: 0.471787
# [46]	valid_0's binary_logloss: 0.471835	valid_0's binary_logloss: 0.471835
# [47]	valid_0's binary_logloss: 0.471812	valid_0's binary_logloss: 0.471812
# [48]	valid_0's binary_logloss: 0.471763	valid_0's binary_logloss: 0.471763
# [49]	valid_0's binary_logloss: 0.471688	valid_0's binary_logloss: 0.471688
# [50]	valid_0's binary_logloss: 0.471727	valid_0's binary_logloss: 0.471727
# [51]	valid_0's binary_logloss: 0.471736	valid_0's binary_logloss: 0.471736
# [52]	valid_0's binary_logloss: 0.471789	valid_0's binary_logloss: 0.471789
# [53]	valid_0's binary_logloss: 0.471878	valid_0's binary_logloss: 0.471878
# [54]	valid_0's binary_logloss: 0.47189	valid_0's binary_logloss: 0.47189
# [55]	valid_0's binary_logloss: 0.471756	valid_0's binary_logloss: 0.471756
# [56]	valid_0's binary_logloss: 0.471905	valid_0's binary_logloss: 0.471905
# [57]	valid_0's binary_logloss: 0.471802	valid_0's binary_logloss: 0.471802
# [58]	valid_0's binary_logloss: 0.471779	valid_0's binary_logloss: 0.471779
# [59]	valid_0's binary_logloss: 0.471686	valid_0's binary_logloss: 0.471686
# [60]	valid_0's binary_logloss: 0.471692	valid_0's binary_logloss: 0.471692
# [61]	valid_0's binary_logloss: 0.47178	valid_0's binary_logloss: 0.47178
# [62]	valid_0's binary_logloss: 0.471748	valid_0's binary_logloss: 0.471748
# [63]	valid_0's binary_logloss: 0.471702	valid_0's binary_logloss: 0.471702
# [64]	valid_0's binary_logloss: 0.471724	valid_0's binary_logloss: 0.471724
# [65]	valid_0's binary_logloss: 0.471708	valid_0's binary_logloss: 0.471708
# [66]	valid_0's binary_logloss: 0.471737	valid_0's binary_logloss: 0.471737
# [67]	valid_0's binary_logloss: 0.471686	valid_0's binary_logloss: 0.471686
# [68]	valid_0's binary_logloss: 0.471636	valid_0's binary_logloss: 0.471636
# [69]	valid_0's binary_logloss: 0.471584	valid_0's binary_logloss: 0.471584
# [70]	valid_0's binary_logloss: 0.47169	valid_0's binary_logloss: 0.47169
# [71]	valid_0's binary_logloss: 0.471636	valid_0's binary_logloss: 0.471636
# [72]	valid_0's binary_logloss: 0.471621	valid_0's binary_logloss: 0.471621
# [73]	valid_0's binary_logloss: 0.4716	valid_0's binary_logloss: 0.4716
# [74]	valid_0's binary_logloss: 0.471629	valid_0's binary_logloss: 0.471629
# [75]	valid_0's binary_logloss: 0.471632	valid_0's binary_logloss: 0.471632
# [76]	valid_0's binary_logloss: 0.471561	valid_0's binary_logloss: 0.471561
# [77]	valid_0's binary_logloss: 0.471621	valid_0's binary_logloss: 0.471621
# [78]	valid_0's binary_logloss: 0.471621	valid_0's binary_logloss: 0.471621
# [79]	valid_0's binary_logloss: 0.471657	valid_0's binary_logloss: 0.471657
# [80]	valid_0's binary_logloss: 0.471641	valid_0's binary_logloss: 0.471641
# [81]	valid_0's binary_logloss: 0.471629	valid_0's binary_logloss: 0.471629
# [82]	valid_0's binary_logloss: 0.471668	valid_0's binary_logloss: 0.471668
# [83]	valid_0's binary_logloss: 0.471681	valid_0's binary_logloss: 0.471681
# [84]	valid_0's binary_logloss: 0.471762	valid_0's binary_logloss: 0.471762
# [85]	valid_0's binary_logloss: 0.471804	valid_0's binary_logloss: 0.471804
# [86]	valid_0's binary_logloss: 0.471792	valid_0's binary_logloss: 0.471792
# [87]	valid_0's binary_logloss: 0.471848	valid_0's binary_logloss: 0.471848
# [88]	valid_0's binary_logloss: 0.471796	valid_0's binary_logloss: 0.471796
# [89]	valid_0's binary_logloss: 0.471851	valid_0's binary_logloss: 0.471851
# [90]	valid_0's binary_logloss: 0.47191	valid_0's binary_logloss: 0.47191
# [91]	valid_0's binary_logloss: 0.471951	valid_0's binary_logloss: 0.471951
# [92]	valid_0's binary_logloss: 0.471913	valid_0's binary_logloss: 0.471913
# [93]	valid_0's binary_logloss: 0.471966	valid_0's binary_logloss: 0.471966
# [94]	valid_0's binary_logloss: 0.472059	valid_0's binary_logloss: 0.472059
# [95]	valid_0's binary_logloss: 0.472059	valid_0's binary_logloss: 0.472059
# [96]	valid_0's binary_logloss: 0.472111	valid_0's binary_logloss: 0.472111
# [97]	valid_0's binary_logloss: 0.4722	valid_0's binary_logloss: 0.4722
# [98]	valid_0's binary_logloss: 0.47226	valid_0's binary_logloss: 0.47226
# [99]	valid_0's binary_logloss: 0.472312	valid_0's binary_logloss: 0.472312
# [100]	valid_0's binary_logloss: 0.472388	valid_0's binary_logloss: 0.472388
# [101]	valid_0's binary_logloss: 0.472406	valid_0's binary_logloss: 0.472406
# [102]	valid_0's binary_logloss: 0.47244	valid_0's binary_logloss: 0.47244
# [103]	valid_0's binary_logloss: 0.472418	valid_0's binary_logloss: 0.472418
# [104]	valid_0's binary_logloss: 0.47246	valid_0's binary_logloss: 0.47246
# [105]	valid_0's binary_logloss: 0.472468	valid_0's binary_logloss: 0.472468
# [106]	valid_0's binary_logloss: 0.472585	valid_0's binary_logloss: 0.472585
# [107]	valid_0's binary_logloss: 0.472602	valid_0's binary_logloss: 0.472602
# [108]	valid_0's binary_logloss: 0.472542	valid_0's binary_logloss: 0.472542
# [109]	valid_0's binary_logloss: 0.472559	valid_0's binary_logloss: 0.472559
# [110]	valid_0's binary_logloss: 0.472591	valid_0's binary_logloss: 0.472591
# [111]	valid_0's binary_logloss: 0.472595	valid_0's binary_logloss: 0.472595
# [112]	valid_0's binary_logloss: 0.472537	valid_0's binary_logloss: 0.472537
# [113]	valid_0's binary_logloss: 0.472531	valid_0's binary_logloss: 0.472531
# [114]	valid_0's binary_logloss: 0.472527	valid_0's binary_logloss: 0.472527
# [115]	valid_0's binary_logloss: 0.4725	valid_0's binary_logloss: 0.4725
# [116]	valid_0's binary_logloss: 0.472509	valid_0's binary_logloss: 0.472509
# [117]	valid_0's binary_logloss: 0.472518	valid_0's binary_logloss: 0.472518
# [118]	valid_0's binary_logloss: 0.472551	valid_0's binary_logloss: 0.472551
# [119]	valid_0's binary_logloss: 0.47254	valid_0's binary_logloss: 0.47254
# [120]	valid_0's binary_logloss: 0.472634	valid_0's binary_logloss: 0.472634
# [121]	valid_0's binary_logloss: 0.472683	valid_0's binary_logloss: 0.472683
# [122]	valid_0's binary_logloss: 0.472706	valid_0's binary_logloss: 0.472706
# [123]	valid_0's binary_logloss: 0.472716	valid_0's binary_logloss: 0.472716
# [124]	valid_0's binary_logloss: 0.472746	valid_0's binary_logloss: 0.472746
# [125]	valid_0's binary_logloss: 0.472734	valid_0's binary_logloss: 0.472734
# [126]	valid_0's binary_logloss: 0.472803	valid_0's binary_logloss: 0.472803
# [127]	valid_0's binary_logloss: 0.472808	valid_0's binary_logloss: 0.472808
# [128]	valid_0's binary_logloss: 0.472794	valid_0's binary_logloss: 0.472794
# [129]	valid_0's binary_logloss: 0.472727	valid_0's binary_logloss: 0.472727
# [130]	valid_0's binary_logloss: 0.472791	valid_0's binary_logloss: 0.472791
# [131]	valid_0's binary_logloss: 0.47286	valid_0's binary_logloss: 0.47286
# [132]	valid_0's binary_logloss: 0.472929	valid_0's binary_logloss: 0.472929
# [133]	valid_0's binary_logloss: 0.472937	valid_0's binary_logloss: 0.472937
# [134]	valid_0's binary_logloss: 0.472922	valid_0's binary_logloss: 0.472922
# [135]	valid_0's binary_logloss: 0.473018	valid_0's binary_logloss: 0.473018
# [136]	valid_0's binary_logloss: 0.473036	valid_0's binary_logloss: 0.473036
# [137]	valid_0's binary_logloss: 0.47306	valid_0's binary_logloss: 0.47306
# [138]	valid_0's binary_logloss: 0.47307	valid_0's binary_logloss: 0.47307
# [139]	valid_0's binary_logloss: 0.473123	valid_0's binary_logloss: 0.473123
# [140]	valid_0's binary_logloss: 0.473178	valid_0's binary_logloss: 0.473178
# [141]	valid_0's binary_logloss: 0.473182	valid_0's binary_logloss: 0.473182
# [142]	valid_0's binary_logloss: 0.473222	valid_0's binary_logloss: 0.473222
# [143]	valid_0's binary_logloss: 0.473277	valid_0's binary_logloss: 0.473277
# [144]	valid_0's binary_logloss: 0.473325	valid_0's binary_logloss: 0.473325
# [145]	valid_0's binary_logloss: 0.473352	valid_0's binary_logloss: 0.473352
# [146]	valid_0's binary_logloss: 0.473308	valid_0's binary_logloss: 0.473308
# [147]	valid_0's binary_logloss: 0.473279	valid_0's binary_logloss: 0.473279
# [148]	valid_0's binary_logloss: 0.473315	valid_0's binary_logloss: 0.473315
# [149]	valid_0's binary_logloss: 0.473393	valid_0's binary_logloss: 0.473393
# [150]	valid_0's binary_logloss: 0.473349	valid_0's binary_logloss: 0.473349
# [151]	valid_0's binary_logloss: 0.47336	valid_0's binary_logloss: 0.47336
# [152]	valid_0's binary_logloss: 0.473401	valid_0's binary_logloss: 0.473401
# [153]	valid_0's binary_logloss: 0.473418	valid_0's binary_logloss: 0.473418
# [154]	valid_0's binary_logloss: 0.473459	valid_0's binary_logloss: 0.473459
# [155]	valid_0's binary_logloss: 0.473446	valid_0's binary_logloss: 0.473446
# [156]	valid_0's binary_logloss: 0.473504	valid_0's binary_logloss: 0.473504
# [157]	valid_0's binary_logloss: 0.473536	valid_0's binary_logloss: 0.473536
# [158]	valid_0's binary_logloss: 0.473574	valid_0's binary_logloss: 0.473574
# [159]	valid_0's binary_logloss: 0.4736	valid_0's binary_logloss: 0.4736
# [160]	valid_0's binary_logloss: 0.473658	valid_0's binary_logloss: 0.473658
# [161]	valid_0's binary_logloss: 0.473688	valid_0's binary_logloss: 0.473688
# [162]	valid_0's binary_logloss: 0.473699	valid_0's binary_logloss: 0.473699
# [163]	valid_0's binary_logloss: 0.473767	valid_0's binary_logloss: 0.473767
# [164]	valid_0's binary_logloss: 0.473836	valid_0's binary_logloss: 0.473836
# [165]	valid_0's binary_logloss: 0.473922	valid_0's binary_logloss: 0.473922
# [166]	valid_0's binary_logloss: 0.473935	valid_0's binary_logloss: 0.473935
# [167]	valid_0's binary_logloss: 0.473996	valid_0's binary_logloss: 0.473996
# [168]	valid_0's binary_logloss: 0.474013	valid_0's binary_logloss: 0.474013
# [169]	valid_0's binary_logloss: 0.474064	valid_0's binary_logloss: 0.474064
# [170]	valid_0's binary_logloss: 0.474057	valid_0's binary_logloss: 0.474057
# [171]	valid_0's binary_logloss: 0.474062	valid_0's binary_logloss: 0.474062
# [172]	valid_0's binary_logloss: 0.474015	valid_0's binary_logloss: 0.474015
# [173]	valid_0's binary_logloss: 0.474084	valid_0's binary_logloss: 0.474084
# [174]	valid_0's binary_logloss: 0.474059	valid_0's binary_logloss: 0.474059
# [175]	valid_0's binary_logloss: 0.474117	valid_0's binary_logloss: 0.474117
# [176]	valid_0's binary_logloss: 0.474117	valid_0's binary_logloss: 0.474117
# Early stopping, best iteration is:
# [76]	valid_0's binary_logloss: 0.471561	valid_0's binary_logloss: 0.471561
# [1]	valid_0's binary_logloss: 0.648908	valid_0's binary_logloss: 0.648908
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.620443	valid_0's binary_logloss: 0.620443
# [3]	valid_0's binary_logloss: 0.597239	valid_0's binary_logloss: 0.597239
# [4]	valid_0's binary_logloss: 0.57902	valid_0's binary_logloss: 0.57902
# [5]	valid_0's binary_logloss: 0.562814	valid_0's binary_logloss: 0.562814
# [6]	valid_0's binary_logloss: 0.556092	valid_0's binary_logloss: 0.556092
# [7]	valid_0's binary_logloss: 0.54757	valid_0's binary_logloss: 0.54757
# [8]	valid_0's binary_logloss: 0.536209	valid_0's binary_logloss: 0.536209
# [9]	valid_0's binary_logloss: 0.526587	valid_0's binary_logloss: 0.526587
# [10]	valid_0's binary_logloss: 0.518797	valid_0's binary_logloss: 0.518797
# [11]	valid_0's binary_logloss: 0.51225	valid_0's binary_logloss: 0.51225
# [12]	valid_0's binary_logloss: 0.506297	valid_0's binary_logloss: 0.506297
# [13]	valid_0's binary_logloss: 0.503493	valid_0's binary_logloss: 0.503493
# [14]	valid_0's binary_logloss: 0.499041	valid_0's binary_logloss: 0.499041
# [15]	valid_0's binary_logloss: 0.495378	valid_0's binary_logloss: 0.495378
# [16]	valid_0's binary_logloss: 0.492321	valid_0's binary_logloss: 0.492321
# [17]	valid_0's binary_logloss: 0.489604	valid_0's binary_logloss: 0.489604
# [18]	valid_0's binary_logloss: 0.48707	valid_0's binary_logloss: 0.48707
# [19]	valid_0's binary_logloss: 0.485446	valid_0's binary_logloss: 0.485446
# [20]	valid_0's binary_logloss: 0.484251	valid_0's binary_logloss: 0.484251
# [21]	valid_0's binary_logloss: 0.482633	valid_0's binary_logloss: 0.482633
# [22]	valid_0's binary_logloss: 0.481087	valid_0's binary_logloss: 0.481087
# [23]	valid_0's binary_logloss: 0.479728	valid_0's binary_logloss: 0.479728
# [24]	valid_0's binary_logloss: 0.478819	valid_0's binary_logloss: 0.478819
# [25]	valid_0's binary_logloss: 0.47823	valid_0's binary_logloss: 0.47823
# [26]	valid_0's binary_logloss: 0.477306	valid_0's binary_logloss: 0.477306
# [27]	valid_0's binary_logloss: 0.47648	valid_0's binary_logloss: 0.47648
# [28]	valid_0's binary_logloss: 0.47563	valid_0's binary_logloss: 0.47563
# [29]	valid_0's binary_logloss: 0.475022	valid_0's binary_logloss: 0.475022
# [30]	valid_0's binary_logloss: 0.474584	valid_0's binary_logloss: 0.474584
# [31]	valid_0's binary_logloss: 0.474154	valid_0's binary_logloss: 0.474154
# [32]	valid_0's binary_logloss: 0.47387	valid_0's binary_logloss: 0.47387
# [33]	valid_0's binary_logloss: 0.473423	valid_0's binary_logloss: 0.473423
# [34]	valid_0's binary_logloss: 0.472969	valid_0's binary_logloss: 0.472969
# [35]	valid_0's binary_logloss: 0.472738	valid_0's binary_logloss: 0.472738
# [36]	valid_0's binary_logloss: 0.472398	valid_0's binary_logloss: 0.472398
# [37]	valid_0's binary_logloss: 0.472041	valid_0's binary_logloss: 0.472041
# [38]	valid_0's binary_logloss: 0.471886	valid_0's binary_logloss: 0.471886
# [39]	valid_0's binary_logloss: 0.47175	valid_0's binary_logloss: 0.47175
# [40]	valid_0's binary_logloss: 0.47176	valid_0's binary_logloss: 0.47176
# [41]	valid_0's binary_logloss: 0.471544	valid_0's binary_logloss: 0.471544
# [42]	valid_0's binary_logloss: 0.471555	valid_0's binary_logloss: 0.471555
# [43]	valid_0's binary_logloss: 0.471447	valid_0's binary_logloss: 0.471447
# [44]	valid_0's binary_logloss: 0.471403	valid_0's binary_logloss: 0.471403
# [45]	valid_0's binary_logloss: 0.471107	valid_0's binary_logloss: 0.471107
# [46]	valid_0's binary_logloss: 0.470873	valid_0's binary_logloss: 0.470873
# [47]	valid_0's binary_logloss: 0.470689	valid_0's binary_logloss: 0.470689
# [48]	valid_0's binary_logloss: 0.470629	valid_0's binary_logloss: 0.470629
# [49]	valid_0's binary_logloss: 0.470554	valid_0's binary_logloss: 0.470554
# [50]	valid_0's binary_logloss: 0.470443	valid_0's binary_logloss: 0.470443
# [51]	valid_0's binary_logloss: 0.470435	valid_0's binary_logloss: 0.470435
# [52]	valid_0's binary_logloss: 0.470325	valid_0's binary_logloss: 0.470325
# [53]	valid_0's binary_logloss: 0.470375	valid_0's binary_logloss: 0.470375
# [54]	valid_0's binary_logloss: 0.470309	valid_0's binary_logloss: 0.470309
# [55]	valid_0's binary_logloss: 0.470329	valid_0's binary_logloss: 0.470329
# [56]	valid_0's binary_logloss: 0.470215	valid_0's binary_logloss: 0.470215
# [57]	valid_0's binary_logloss: 0.470103	valid_0's binary_logloss: 0.470103
# [58]	valid_0's binary_logloss: 0.470117	valid_0's binary_logloss: 0.470117
# [59]	valid_0's binary_logloss: 0.470144	valid_0's binary_logloss: 0.470144
# [60]	valid_0's binary_logloss: 0.470077	valid_0's binary_logloss: 0.470077
# [61]	valid_0's binary_logloss: 0.470054	valid_0's binary_logloss: 0.470054
# [62]	valid_0's binary_logloss: 0.470064	valid_0's binary_logloss: 0.470064
# [63]	valid_0's binary_logloss: 0.469993	valid_0's binary_logloss: 0.469993
# [64]	valid_0's binary_logloss: 0.469948	valid_0's binary_logloss: 0.469948
# [65]	valid_0's binary_logloss: 0.470002	valid_0's binary_logloss: 0.470002
# [66]	valid_0's binary_logloss: 0.470001	valid_0's binary_logloss: 0.470001
# [67]	valid_0's binary_logloss: 0.469966	valid_0's binary_logloss: 0.469966
# [68]	valid_0's binary_logloss: 0.469878	valid_0's binary_logloss: 0.469878
# [69]	valid_0's binary_logloss: 0.469884	valid_0's binary_logloss: 0.469884
# [70]	valid_0's binary_logloss: 0.469843	valid_0's binary_logloss: 0.469843
# [71]	valid_0's binary_logloss: 0.469832	valid_0's binary_logloss: 0.469832
# [72]	valid_0's binary_logloss: 0.469834	valid_0's binary_logloss: 0.469834
# [73]	valid_0's binary_logloss: 0.469836	valid_0's binary_logloss: 0.469836
# [74]	valid_0's binary_logloss: 0.469894	valid_0's binary_logloss: 0.469894
# [75]	valid_0's binary_logloss: 0.469885	valid_0's binary_logloss: 0.469885
# [76]	valid_0's binary_logloss: 0.469941	valid_0's binary_logloss: 0.469941
# [77]	valid_0's binary_logloss: 0.469974	valid_0's binary_logloss: 0.469974
# [78]	valid_0's binary_logloss: 0.469985	valid_0's binary_logloss: 0.469985
# [79]	valid_0's binary_logloss: 0.469904	valid_0's binary_logloss: 0.469904
# [80]	valid_0's binary_logloss: 0.469886	valid_0's binary_logloss: 0.469886
# [81]	valid_0's binary_logloss: 0.469848	valid_0's binary_logloss: 0.469848
# [82]	valid_0's binary_logloss: 0.469925	valid_0's binary_logloss: 0.469925
# [83]	valid_0's binary_logloss: 0.469862	valid_0's binary_logloss: 0.469862
# [84]	valid_0's binary_logloss: 0.469825	valid_0's binary_logloss: 0.469825
# [85]	valid_0's binary_logloss: 0.469762	valid_0's binary_logloss: 0.469762
# [86]	valid_0's binary_logloss: 0.469716	valid_0's binary_logloss: 0.469716
# [87]	valid_0's binary_logloss: 0.469682	valid_0's binary_logloss: 0.469682
# [88]	valid_0's binary_logloss: 0.469692	valid_0's binary_logloss: 0.469692
# [89]	valid_0's binary_logloss: 0.4697	valid_0's binary_logloss: 0.4697
# [90]	valid_0's binary_logloss: 0.469679	valid_0's binary_logloss: 0.469679
# [91]	valid_0's binary_logloss: 0.46969	valid_0's binary_logloss: 0.46969
# [92]	valid_0's binary_logloss: 0.469686	valid_0's binary_logloss: 0.469686
# [93]	valid_0's binary_logloss: 0.469655	valid_0's binary_logloss: 0.469655
# [94]	valid_0's binary_logloss: 0.46963	valid_0's binary_logloss: 0.46963
# [95]	valid_0's binary_logloss: 0.469597	valid_0's binary_logloss: 0.469597
# [96]	valid_0's binary_logloss: 0.469633	valid_0's binary_logloss: 0.469633
# [97]	valid_0's binary_logloss: 0.469577	valid_0's binary_logloss: 0.469577
# [98]	valid_0's binary_logloss: 0.469616	valid_0's binary_logloss: 0.469616
# [99]	valid_0's binary_logloss: 0.469657	valid_0's binary_logloss: 0.469657
# [100]	valid_0's binary_logloss: 0.469716	valid_0's binary_logloss: 0.469716
# [101]	valid_0's binary_logloss: 0.469747	valid_0's binary_logloss: 0.469747
# [102]	valid_0's binary_logloss: 0.469772	valid_0's binary_logloss: 0.469772
# [103]	valid_0's binary_logloss: 0.469685	valid_0's binary_logloss: 0.469685
# [104]	valid_0's binary_logloss: 0.469747	valid_0's binary_logloss: 0.469747
# [105]	valid_0's binary_logloss: 0.469808	valid_0's binary_logloss: 0.469808
# [106]	valid_0's binary_logloss: 0.469835	valid_0's binary_logloss: 0.469835
# [107]	valid_0's binary_logloss: 0.469826	valid_0's binary_logloss: 0.469826
# [108]	valid_0's binary_logloss: 0.469869	valid_0's binary_logloss: 0.469869
# [109]	valid_0's binary_logloss: 0.469861	valid_0's binary_logloss: 0.469861
# [110]	valid_0's binary_logloss: 0.469892	valid_0's binary_logloss: 0.469892
# [111]	valid_0's binary_logloss: 0.469834	valid_0's binary_logloss: 0.469834
# [112]	valid_0's binary_logloss: 0.469839	valid_0's binary_logloss: 0.469839
# [113]	valid_0's binary_logloss: 0.469804	valid_0's binary_logloss: 0.469804
# [114]	valid_0's binary_logloss: 0.469836	valid_0's binary_logloss: 0.469836
# [115]	valid_0's binary_logloss: 0.469818	valid_0's binary_logloss: 0.469818
# [116]	valid_0's binary_logloss: 0.469861	valid_0's binary_logloss: 0.469861
# [117]	valid_0's binary_logloss: 0.46986	valid_0's binary_logloss: 0.46986
# [118]	valid_0's binary_logloss: 0.469885	valid_0's binary_logloss: 0.469885
# [119]	valid_0's binary_logloss: 0.469856	valid_0's binary_logloss: 0.469856
# [120]	valid_0's binary_logloss: 0.469842	valid_0's binary_logloss: 0.469842
# [121]	valid_0's binary_logloss: 0.469771	valid_0's binary_logloss: 0.469771
# [122]	valid_0's binary_logloss: 0.469717	valid_0's binary_logloss: 0.469717
# [123]	valid_0's binary_logloss: 0.469712	valid_0's binary_logloss: 0.469712
# [124]	valid_0's binary_logloss: 0.469686	valid_0's binary_logloss: 0.469686
# [125]	valid_0's binary_logloss: 0.469683	valid_0's binary_logloss: 0.469683
# [126]	valid_0's binary_logloss: 0.469688	valid_0's binary_logloss: 0.469688
# [127]	valid_0's binary_logloss: 0.469634	valid_0's binary_logloss: 0.469634
# [128]	valid_0's binary_logloss: 0.469635	valid_0's binary_logloss: 0.469635
# [129]	valid_0's binary_logloss: 0.469693	valid_0's binary_logloss: 0.469693
# [130]	valid_0's binary_logloss: 0.469752	valid_0's binary_logloss: 0.469752
# [131]	valid_0's binary_logloss: 0.46981	valid_0's binary_logloss: 0.46981
# [132]	valid_0's binary_logloss: 0.469796	valid_0's binary_logloss: 0.469796
# [133]	valid_0's binary_logloss: 0.469782	valid_0's binary_logloss: 0.469782
# [134]	valid_0's binary_logloss: 0.469894	valid_0's binary_logloss: 0.469894
# [135]	valid_0's binary_logloss: 0.469939	valid_0's binary_logloss: 0.469939
# [136]	valid_0's binary_logloss: 0.470009	valid_0's binary_logloss: 0.470009
# [137]	valid_0's binary_logloss: 0.470001	valid_0's binary_logloss: 0.470001
# [138]	valid_0's binary_logloss: 0.470033	valid_0's binary_logloss: 0.470033
# [139]	valid_0's binary_logloss: 0.469982	valid_0's binary_logloss: 0.469982
# [140]	valid_0's binary_logloss: 0.470038	valid_0's binary_logloss: 0.470038
# [141]	valid_0's binary_logloss: 0.470018	valid_0's binary_logloss: 0.470018
# [142]	valid_0's binary_logloss: 0.470069	valid_0's binary_logloss: 0.470069
# [143]	valid_0's binary_logloss: 0.470031	valid_0's binary_logloss: 0.470031
# [144]	valid_0's binary_logloss: 0.47007	valid_0's binary_logloss: 0.47007
# [145]	valid_0's binary_logloss: 0.470092	valid_0's binary_logloss: 0.470092
# [146]	valid_0's binary_logloss: 0.470149	valid_0's binary_logloss: 0.470149
# [147]	valid_0's binary_logloss: 0.470173	valid_0's binary_logloss: 0.470173
# [148]	valid_0's binary_logloss: 0.470189	valid_0's binary_logloss: 0.470189
# [149]	valid_0's binary_logloss: 0.470134	valid_0's binary_logloss: 0.470134
# [150]	valid_0's binary_logloss: 0.470132	valid_0's binary_logloss: 0.470132
# [151]	valid_0's binary_logloss: 0.470148	valid_0's binary_logloss: 0.470148
# [152]	valid_0's binary_logloss: 0.470132	valid_0's binary_logloss: 0.470132
# [153]	valid_0's binary_logloss: 0.470097	valid_0's binary_logloss: 0.470097
# [154]	valid_0's binary_logloss: 0.470096	valid_0's binary_logloss: 0.470096
# [155]	valid_0's binary_logloss: 0.470118	valid_0's binary_logloss: 0.470118
# [156]	valid_0's binary_logloss: 0.470093	valid_0's binary_logloss: 0.470093
# [157]	valid_0's binary_logloss: 0.470151	valid_0's binary_logloss: 0.470151
# [158]	valid_0's binary_logloss: 0.470194	valid_0's binary_logloss: 0.470194
# [159]	valid_0's binary_logloss: 0.470191	valid_0's binary_logloss: 0.470191
# [160]	valid_0's binary_logloss: 0.470199	valid_0's binary_logloss: 0.470199
# [161]	valid_0's binary_logloss: 0.470225	valid_0's binary_logloss: 0.470225
# [162]	valid_0's binary_logloss: 0.470211	valid_0's binary_logloss: 0.470211
# [163]	valid_0's binary_logloss: 0.470187	valid_0's binary_logloss: 0.470187
# [164]	valid_0's binary_logloss: 0.47017	valid_0's binary_logloss: 0.47017
# [165]	valid_0's binary_logloss: 0.470133	valid_0's binary_logloss: 0.470133
# [166]	valid_0's binary_logloss: 0.470221	valid_0's binary_logloss: 0.470221
# [167]	valid_0's binary_logloss: 0.470238	valid_0's binary_logloss: 0.470238
# [168]	valid_0's binary_logloss: 0.470222	valid_0's binary_logloss: 0.470222
# [169]	valid_0's binary_logloss: 0.470234	valid_0's binary_logloss: 0.470234
# [170]	valid_0's binary_logloss: 0.470268	valid_0's binary_logloss: 0.470268
# [171]	valid_0's binary_logloss: 0.470242	valid_0's binary_logloss: 0.470242
# [172]	valid_0's binary_logloss: 0.470241	valid_0's binary_logloss: 0.470241
# [173]	valid_0's binary_logloss: 0.470267	valid_0's binary_logloss: 0.470267
# [174]	valid_0's binary_logloss: 0.470207	valid_0's binary_logloss: 0.470207
# [175]	valid_0's binary_logloss: 0.470198	valid_0's binary_logloss: 0.470198
# [176]	valid_0's binary_logloss: 0.470195	valid_0's binary_logloss: 0.470195
# [177]	valid_0's binary_logloss: 0.470198	valid_0's binary_logloss: 0.470198
# [178]	valid_0's binary_logloss: 0.470183	valid_0's binary_logloss: 0.470183
# [179]	valid_0's binary_logloss: 0.470198	valid_0's binary_logloss: 0.470198
# [180]	valid_0's binary_logloss: 0.470198	valid_0's binary_logloss: 0.470198
# [181]	valid_0's binary_logloss: 0.470113	valid_0's binary_logloss: 0.470113
# [182]	valid_0's binary_logloss: 0.470103	valid_0's binary_logloss: 0.470103
# [183]	valid_0's binary_logloss: 0.470191	valid_0's binary_logloss: 0.470191
# [184]	valid_0's binary_logloss: 0.470188	valid_0's binary_logloss: 0.470188
# [185]	valid_0's binary_logloss: 0.470223	valid_0's binary_logloss: 0.470223
# [186]	valid_0's binary_logloss: 0.470227	valid_0's binary_logloss: 0.470227
# [187]	valid_0's binary_logloss: 0.470165	valid_0's binary_logloss: 0.470165
# [188]	valid_0's binary_logloss: 0.470139	valid_0's binary_logloss: 0.470139
# [189]	valid_0's binary_logloss: 0.470144	valid_0's binary_logloss: 0.470144
# [190]	valid_0's binary_logloss: 0.470104	valid_0's binary_logloss: 0.470104
# [191]	valid_0's binary_logloss: 0.470164	valid_0's binary_logloss: 0.470164
# [192]	valid_0's binary_logloss: 0.470202	valid_0's binary_logloss: 0.470202
# [193]	valid_0's binary_logloss: 0.470215	valid_0's binary_logloss: 0.470215
# [194]	valid_0's binary_logloss: 0.470216	valid_0's binary_logloss: 0.470216
# [195]	valid_0's binary_logloss: 0.470309	valid_0's binary_logloss: 0.470309
# [196]	valid_0's binary_logloss: 0.470294	valid_0's binary_logloss: 0.470294
# [197]	valid_0's binary_logloss: 0.470172	valid_0's binary_logloss: 0.470172
# Early stopping, best iteration is:
# [97]	valid_0's binary_logloss: 0.469577	valid_0's binary_logloss: 0.469577
# [1]	valid_0's binary_logloss: 0.649034	valid_0's binary_logloss: 0.649034
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.620737	valid_0's binary_logloss: 0.620737
# [3]	valid_0's binary_logloss: 0.597669	valid_0's binary_logloss: 0.597669
# [4]	valid_0's binary_logloss: 0.579263	valid_0's binary_logloss: 0.579263
# [5]	valid_0's binary_logloss: 0.562988	valid_0's binary_logloss: 0.562988
# [6]	valid_0's binary_logloss: 0.556481	valid_0's binary_logloss: 0.556481
# [7]	valid_0's binary_logloss: 0.547715	valid_0's binary_logloss: 0.547715
# [8]	valid_0's binary_logloss: 0.536367	valid_0's binary_logloss: 0.536367
# [9]	valid_0's binary_logloss: 0.526877	valid_0's binary_logloss: 0.526877
# [10]	valid_0's binary_logloss: 0.519206	valid_0's binary_logloss: 0.519206
# [11]	valid_0's binary_logloss: 0.512728	valid_0's binary_logloss: 0.512728
# [12]	valid_0's binary_logloss: 0.506645	valid_0's binary_logloss: 0.506645
# [13]	valid_0's binary_logloss: 0.503817	valid_0's binary_logloss: 0.503817
# [14]	valid_0's binary_logloss: 0.499406	valid_0's binary_logloss: 0.499406
# [15]	valid_0's binary_logloss: 0.495723	valid_0's binary_logloss: 0.495723
# [16]	valid_0's binary_logloss: 0.492662	valid_0's binary_logloss: 0.492662
# [17]	valid_0's binary_logloss: 0.489627	valid_0's binary_logloss: 0.489627
# [18]	valid_0's binary_logloss: 0.487201	valid_0's binary_logloss: 0.487201
# [19]	valid_0's binary_logloss: 0.48544	valid_0's binary_logloss: 0.48544
# [20]	valid_0's binary_logloss: 0.484091	valid_0's binary_logloss: 0.484091
# [21]	valid_0's binary_logloss: 0.482386	valid_0's binary_logloss: 0.482386
# [22]	valid_0's binary_logloss: 0.480697	valid_0's binary_logloss: 0.480697
# [23]	valid_0's binary_logloss: 0.479423	valid_0's binary_logloss: 0.479423
# [24]	valid_0's binary_logloss: 0.478504	valid_0's binary_logloss: 0.478504
# [25]	valid_0's binary_logloss: 0.477857	valid_0's binary_logloss: 0.477857
# [26]	valid_0's binary_logloss: 0.476936	valid_0's binary_logloss: 0.476936
# [27]	valid_0's binary_logloss: 0.476138	valid_0's binary_logloss: 0.476138
# [28]	valid_0's binary_logloss: 0.475369	valid_0's binary_logloss: 0.475369
# [29]	valid_0's binary_logloss: 0.474769	valid_0's binary_logloss: 0.474769
# [30]	valid_0's binary_logloss: 0.474184	valid_0's binary_logloss: 0.474184
# [31]	valid_0's binary_logloss: 0.473615	valid_0's binary_logloss: 0.473615
# [32]	valid_0's binary_logloss: 0.473192	valid_0's binary_logloss: 0.473192
# [33]	valid_0's binary_logloss: 0.47272	valid_0's binary_logloss: 0.47272
# [34]	valid_0's binary_logloss: 0.47244	valid_0's binary_logloss: 0.47244
# [35]	valid_0's binary_logloss: 0.472165	valid_0's binary_logloss: 0.472165
# [36]	valid_0's binary_logloss: 0.471848	valid_0's binary_logloss: 0.471848
# [37]	valid_0's binary_logloss: 0.471584	valid_0's binary_logloss: 0.471584
# [38]	valid_0's binary_logloss: 0.47135	valid_0's binary_logloss: 0.47135
# [39]	valid_0's binary_logloss: 0.471176	valid_0's binary_logloss: 0.471176
# [40]	valid_0's binary_logloss: 0.47102	valid_0's binary_logloss: 0.47102
# [41]	valid_0's binary_logloss: 0.470759	valid_0's binary_logloss: 0.470759
# [42]	valid_0's binary_logloss: 0.470708	valid_0's binary_logloss: 0.470708
# [43]	valid_0's binary_logloss: 0.470597	valid_0's binary_logloss: 0.470597
# [44]	valid_0's binary_logloss: 0.470514	valid_0's binary_logloss: 0.470514
# [45]	valid_0's binary_logloss: 0.470239	valid_0's binary_logloss: 0.470239
# [46]	valid_0's binary_logloss: 0.470096	valid_0's binary_logloss: 0.470096
# [47]	valid_0's binary_logloss: 0.469974	valid_0's binary_logloss: 0.469974
# [48]	valid_0's binary_logloss: 0.469925	valid_0's binary_logloss: 0.469925
# [49]	valid_0's binary_logloss: 0.469808	valid_0's binary_logloss: 0.469808
# [50]	valid_0's binary_logloss: 0.469751	valid_0's binary_logloss: 0.469751
# [51]	valid_0's binary_logloss: 0.469715	valid_0's binary_logloss: 0.469715
# [52]	valid_0's binary_logloss: 0.469668	valid_0's binary_logloss: 0.469668
# [53]	valid_0's binary_logloss: 0.469672	valid_0's binary_logloss: 0.469672
# [54]	valid_0's binary_logloss: 0.469614	valid_0's binary_logloss: 0.469614
# [55]	valid_0's binary_logloss: 0.469512	valid_0's binary_logloss: 0.469512
# [56]	valid_0's binary_logloss: 0.469454	valid_0's binary_logloss: 0.469454
# [57]	valid_0's binary_logloss: 0.469358	valid_0's binary_logloss: 0.469358
# [58]	valid_0's binary_logloss: 0.469229	valid_0's binary_logloss: 0.469229
# [59]	valid_0's binary_logloss: 0.469245	valid_0's binary_logloss: 0.469245
# [60]	valid_0's binary_logloss: 0.469205	valid_0's binary_logloss: 0.469205
# [61]	valid_0's binary_logloss: 0.469215	valid_0's binary_logloss: 0.469215
# [62]	valid_0's binary_logloss: 0.469161	valid_0's binary_logloss: 0.469161
# [63]	valid_0's binary_logloss: 0.46913	valid_0's binary_logloss: 0.46913
# [64]	valid_0's binary_logloss: 0.469111	valid_0's binary_logloss: 0.469111
# [65]	valid_0's binary_logloss: 0.469094	valid_0's binary_logloss: 0.469094
# [66]	valid_0's binary_logloss: 0.469015	valid_0's binary_logloss: 0.469015
# [67]	valid_0's binary_logloss: 0.468995	valid_0's binary_logloss: 0.468995
# [68]	valid_0's binary_logloss: 0.469066	valid_0's binary_logloss: 0.469066
# [69]	valid_0's binary_logloss: 0.469033	valid_0's binary_logloss: 0.469033
# [70]	valid_0's binary_logloss: 0.468996	valid_0's binary_logloss: 0.468996
# [71]	valid_0's binary_logloss: 0.469043	valid_0's binary_logloss: 0.469043
# [72]	valid_0's binary_logloss: 0.468971	valid_0's binary_logloss: 0.468971
# [73]	valid_0's binary_logloss: 0.46899	valid_0's binary_logloss: 0.46899
# [74]	valid_0's binary_logloss: 0.469014	valid_0's binary_logloss: 0.469014
# [75]	valid_0's binary_logloss: 0.468997	valid_0's binary_logloss: 0.468997
# [76]	valid_0's binary_logloss: 0.469039	valid_0's binary_logloss: 0.469039
# [77]	valid_0's binary_logloss: 0.469088	valid_0's binary_logloss: 0.469088
# [78]	valid_0's binary_logloss: 0.46915	valid_0's binary_logloss: 0.46915
# [79]	valid_0's binary_logloss: 0.469156	valid_0's binary_logloss: 0.469156
# [80]	valid_0's binary_logloss: 0.469171	valid_0's binary_logloss: 0.469171
# [81]	valid_0's binary_logloss: 0.469127	valid_0's binary_logloss: 0.469127
# [82]	valid_0's binary_logloss: 0.46913	valid_0's binary_logloss: 0.46913
# [83]	valid_0's binary_logloss: 0.469124	valid_0's binary_logloss: 0.469124
# [84]	valid_0's binary_logloss: 0.469166	valid_0's binary_logloss: 0.469166
# ...
# [6]	valid_0's binary_logloss: 0.554902	valid_0's binary_logloss: 0.554902
# [7]	valid_0's binary_logloss: 0.546201	valid_0's binary_logloss: 0.546201
# [8]	valid_0's binary_logloss: 0.5346	valid_0's binary_logloss: 0.5346
# [9]	valid_0's binary_logloss: 0.524871	valid_0's binary_logloss: 0.524871
# [10]	valid_0's binary_logloss: 0.51681	valid_0's binary_logloss: 0.51681
# [11]	valid_0's binary_logloss: 0.510069	valid_0's binary_logloss: 0.510069
# [12]	valid_0's binary_logloss: 0.503691	valid_0's binary_logloss: 0.503691
# [13]	valid_0's binary_logloss: 0.50095	valid_0's binary_logloss: 0.50095
# [14]	valid_0's binary_logloss: 0.496239	valid_0's binary_logloss: 0.496239
# [15]	valid_0's binary_logloss: 0.492305	valid_0's binary_logloss: 0.492305
# [16]	valid_0's binary_logloss: 0.488947	valid_0's binary_logloss: 0.488947
# [17]	valid_0's binary_logloss: 0.485719	valid_0's binary_logloss: 0.485719
# [18]	valid_0's binary_logloss: 0.482959	valid_0's binary_logloss: 0.482959
# [19]	valid_0's binary_logloss: 0.481204	valid_0's binary_logloss: 0.481204
# [20]	valid_0's binary_logloss: 0.479921	valid_0's binary_logloss: 0.479921
# [21]	valid_0's binary_logloss: 0.478109	valid_0's binary_logloss: 0.478109
# [22]	valid_0's binary_logloss: 0.476283	valid_0's binary_logloss: 0.476283
# [23]	valid_0's binary_logloss: 0.474839	valid_0's binary_logloss: 0.474839
# [24]	valid_0's binary_logloss: 0.473959	valid_0's binary_logloss: 0.473959
# [25]	valid_0's binary_logloss: 0.473307	valid_0's binary_logloss: 0.473307
# [26]	valid_0's binary_logloss: 0.472322	valid_0's binary_logloss: 0.472322
# [27]	valid_0's binary_logloss: 0.47145	valid_0's binary_logloss: 0.47145
# [28]	valid_0's binary_logloss: 0.470443	valid_0's binary_logloss: 0.470443
# [29]	valid_0's binary_logloss: 0.469817	valid_0's binary_logloss: 0.469817
# [30]	valid_0's binary_logloss: 0.469142	valid_0's binary_logloss: 0.469142
# [31]	valid_0's binary_logloss: 0.468463	valid_0's binary_logloss: 0.468463
# [32]	valid_0's binary_logloss: 0.468003	valid_0's binary_logloss: 0.468003
# [33]	valid_0's binary_logloss: 0.467434	valid_0's binary_logloss: 0.467434
# [34]	valid_0's binary_logloss: 0.467055	valid_0's binary_logloss: 0.467055
# [35]	valid_0's binary_logloss: 0.466585	valid_0's binary_logloss: 0.466585
# [36]	valid_0's binary_logloss: 0.466367	valid_0's binary_logloss: 0.466367
# [37]	valid_0's binary_logloss: 0.46606	valid_0's binary_logloss: 0.46606
# [38]	valid_0's binary_logloss: 0.46569	valid_0's binary_logloss: 0.46569
# [39]	valid_0's binary_logloss: 0.465442	valid_0's binary_logloss: 0.465442
# [40]	valid_0's binary_logloss: 0.465246	valid_0's binary_logloss: 0.465246
# [41]	valid_0's binary_logloss: 0.465022	valid_0's binary_logloss: 0.465022
# [42]	valid_0's binary_logloss: 0.464899	valid_0's binary_logloss: 0.464899
# [43]	valid_0's binary_logloss: 0.464714	valid_0's binary_logloss: 0.464714
# [44]	valid_0's binary_logloss: 0.464554	valid_0's binary_logloss: 0.464554
# [45]	valid_0's binary_logloss: 0.464355	valid_0's binary_logloss: 0.464355
# [46]	valid_0's binary_logloss: 0.464333	valid_0's binary_logloss: 0.464333
# [47]	valid_0's binary_logloss: 0.464222	valid_0's binary_logloss: 0.464222
# [48]	valid_0's binary_logloss: 0.464071	valid_0's binary_logloss: 0.464071
# [49]	valid_0's binary_logloss: 0.463991	valid_0's binary_logloss: 0.463991
# [50]	valid_0's binary_logloss: 0.463969	valid_0's binary_logloss: 0.463969
# [51]	valid_0's binary_logloss: 0.463915	valid_0's binary_logloss: 0.463915
# [52]	valid_0's binary_logloss: 0.463914	valid_0's binary_logloss: 0.463914
# [53]	valid_0's binary_logloss: 0.463931	valid_0's binary_logloss: 0.463931
# [54]	valid_0's binary_logloss: 0.463818	valid_0's binary_logloss: 0.463818
# [55]	valid_0's binary_logloss: 0.463721	valid_0's binary_logloss: 0.463721
# [56]	valid_0's binary_logloss: 0.46352	valid_0's binary_logloss: 0.46352
# [57]	valid_0's binary_logloss: 0.463508	valid_0's binary_logloss: 0.463508
# [58]	valid_0's binary_logloss: 0.463409	valid_0's binary_logloss: 0.463409
# [59]	valid_0's binary_logloss: 0.463359	valid_0's binary_logloss: 0.463359
# [60]	valid_0's binary_logloss: 0.463183	valid_0's binary_logloss: 0.463183
# [61]	valid_0's binary_logloss: 0.463174	valid_0's binary_logloss: 0.463174
# [62]	valid_0's binary_logloss: 0.463167	valid_0's binary_logloss: 0.463167
# [63]	valid_0's binary_logloss: 0.463166	valid_0's binary_logloss: 0.463166
# [64]	valid_0's binary_logloss: 0.463178	valid_0's binary_logloss: 0.463178
# [65]	valid_0's binary_logloss: 0.46312	valid_0's binary_logloss: 0.46312
# [66]	valid_0's binary_logloss: 0.4631	valid_0's binary_logloss: 0.4631
# [67]	valid_0's binary_logloss: 0.463074	valid_0's binary_logloss: 0.463074
# [68]	valid_0's binary_logloss: 0.463049	valid_0's binary_logloss: 0.463049
# [69]	valid_0's binary_logloss: 0.463034	valid_0's binary_logloss: 0.463034
# [70]	valid_0's binary_logloss: 0.463	valid_0's binary_logloss: 0.463
# [71]	valid_0's binary_logloss: 0.463018	valid_0's binary_logloss: 0.463018
# [72]	valid_0's binary_logloss: 0.463011	valid_0's binary_logloss: 0.463011
# [73]	valid_0's binary_logloss: 0.463069	valid_0's binary_logloss: 0.463069
# [74]	valid_0's binary_logloss: 0.463101	valid_0's binary_logloss: 0.463101
# [75]	valid_0's binary_logloss: 0.463155	valid_0's binary_logloss: 0.463155
# [76]	valid_0's binary_logloss: 0.463138	valid_0's binary_logloss: 0.463138
# [77]	valid_0's binary_logloss: 0.463223	valid_0's binary_logloss: 0.463223
# [78]	valid_0's binary_logloss: 0.463214	valid_0's binary_logloss: 0.463214
# [79]	valid_0's binary_logloss: 0.463136	valid_0's binary_logloss: 0.463136
# [80]	valid_0's binary_logloss: 0.46302	valid_0's binary_logloss: 0.46302
# [81]	valid_0's binary_logloss: 0.462965	valid_0's binary_logloss: 0.462965
# [82]	valid_0's binary_logloss: 0.462881	valid_0's binary_logloss: 0.462881
# [83]	valid_0's binary_logloss: 0.462789	valid_0's binary_logloss: 0.462789
# [84]	valid_0's binary_logloss: 0.462756	valid_0's binary_logloss: 0.462756
# [85]	valid_0's binary_logloss: 0.462724	valid_0's binary_logloss: 0.462724
# [86]	valid_0's binary_logloss: 0.462711	valid_0's binary_logloss: 0.462711
# [87]	valid_0's binary_logloss: 0.462715	valid_0's binary_logloss: 0.462715
# [88]	valid_0's binary_logloss: 0.462688	valid_0's binary_logloss: 0.462688
# [89]	valid_0's binary_logloss: 0.462736	valid_0's binary_logloss: 0.462736
# [90]	valid_0's binary_logloss: 0.462753	valid_0's binary_logloss: 0.462753
# [91]	valid_0's binary_logloss: 0.462778	valid_0's binary_logloss: 0.462778
# [92]	valid_0's binary_logloss: 0.462708	valid_0's binary_logloss: 0.462708
# [93]	valid_0's binary_logloss: 0.46278	valid_0's binary_logloss: 0.46278
# [94]	valid_0's binary_logloss: 0.462745	valid_0's binary_logloss: 0.462745
# [95]	valid_0's binary_logloss: 0.462726	valid_0's binary_logloss: 0.462726
# [96]	valid_0's binary_logloss: 0.462732	valid_0's binary_logloss: 0.462732
# [97]	valid_0's binary_logloss: 0.462735	valid_0's binary_logloss: 0.462735
# [98]	valid_0's binary_logloss: 0.462725	valid_0's binary_logloss: 0.462725
# [99]	valid_0's binary_logloss: 0.462708	valid_0's binary_logloss: 0.462708
# [100]	valid_0's binary_logloss: 0.462752	valid_0's binary_logloss: 0.462752
# [101]	valid_0's binary_logloss: 0.462778	valid_0's binary_logloss: 0.462778
# [102]	valid_0's binary_logloss: 0.462813	valid_0's binary_logloss: 0.462813
# [103]	valid_0's binary_logloss: 0.462827	valid_0's binary_logloss: 0.462827
# [104]	valid_0's binary_logloss: 0.462761	valid_0's binary_logloss: 0.462761
# [105]	valid_0's binary_logloss: 0.462726	valid_0's binary_logloss: 0.462726
# [106]	valid_0's binary_logloss: 0.462672	valid_0's binary_logloss: 0.462672
# [107]	valid_0's binary_logloss: 0.462691	valid_0's binary_logloss: 0.462691
# [108]	valid_0's binary_logloss: 0.462682	valid_0's binary_logloss: 0.462682
# [109]	valid_0's binary_logloss: 0.462714	valid_0's binary_logloss: 0.462714
# [110]	valid_0's binary_logloss: 0.462713	valid_0's binary_logloss: 0.462713
# [111]	valid_0's binary_logloss: 0.462738	valid_0's binary_logloss: 0.462738
# [112]	valid_0's binary_logloss: 0.462721	valid_0's binary_logloss: 0.462721
# [113]	valid_0's binary_logloss: 0.462702	valid_0's binary_logloss: 0.462702
# [114]	valid_0's binary_logloss: 0.462678	valid_0's binary_logloss: 0.462678
# [115]	valid_0's binary_logloss: 0.46262	valid_0's binary_logloss: 0.46262
# [116]	valid_0's binary_logloss: 0.462702	valid_0's binary_logloss: 0.462702
# [117]	valid_0's binary_logloss: 0.462711	valid_0's binary_logloss: 0.462711
# [118]	valid_0's binary_logloss: 0.462737	valid_0's binary_logloss: 0.462737
# [119]	valid_0's binary_logloss: 0.46277	valid_0's binary_logloss: 0.46277
# [120]	valid_0's binary_logloss: 0.462697	valid_0's binary_logloss: 0.462697
# [121]	valid_0's binary_logloss: 0.462689	valid_0's binary_logloss: 0.462689
# [122]	valid_0's binary_logloss: 0.462642	valid_0's binary_logloss: 0.462642
# [123]	valid_0's binary_logloss: 0.462663	valid_0's binary_logloss: 0.462663
# [124]	valid_0's binary_logloss: 0.46272	valid_0's binary_logloss: 0.46272
# [125]	valid_0's binary_logloss: 0.462682	valid_0's binary_logloss: 0.462682
# [126]	valid_0's binary_logloss: 0.462621	valid_0's binary_logloss: 0.462621
# [127]	valid_0's binary_logloss: 0.462629	valid_0's binary_logloss: 0.462629
# [128]	valid_0's binary_logloss: 0.462639	valid_0's binary_logloss: 0.462639
# [129]	valid_0's binary_logloss: 0.462665	valid_0's binary_logloss: 0.462665
# [130]	valid_0's binary_logloss: 0.462666	valid_0's binary_logloss: 0.462666
# [131]	valid_0's binary_logloss: 0.462691	valid_0's binary_logloss: 0.462691
# [132]	valid_0's binary_logloss: 0.462689	valid_0's binary_logloss: 0.462689
# [133]	valid_0's binary_logloss: 0.462694	valid_0's binary_logloss: 0.462694
# [134]	valid_0's binary_logloss: 0.462719	valid_0's binary_logloss: 0.462719
# [135]	valid_0's binary_logloss: 0.46282	valid_0's binary_logloss: 0.46282
# [136]	valid_0's binary_logloss: 0.462777	valid_0's binary_logloss: 0.462777
# [137]	valid_0's binary_logloss: 0.46279	valid_0's binary_logloss: 0.46279
# [138]	valid_0's binary_logloss: 0.46283	valid_0's binary_logloss: 0.46283
# [139]	valid_0's binary_logloss: 0.462839	valid_0's binary_logloss: 0.462839
# [140]	valid_0's binary_logloss: 0.462839	valid_0's binary_logloss: 0.462839
# [141]	valid_0's binary_logloss: 0.462832	valid_0's binary_logloss: 0.462832
# [142]	valid_0's binary_logloss: 0.462878	valid_0's binary_logloss: 0.462878
# [143]	valid_0's binary_logloss: 0.462892	valid_0's binary_logloss: 0.462892
# [144]	valid_0's binary_logloss: 0.462869	valid_0's binary_logloss: 0.462869
# [145]	valid_0's binary_logloss: 0.462846	valid_0's binary_logloss: 0.462846
# [146]	valid_0's binary_logloss: 0.462847	valid_0's binary_logloss: 0.462847
# [147]	valid_0's binary_logloss: 0.462896	valid_0's binary_logloss: 0.462896
# [148]	valid_0's binary_logloss: 0.462874	valid_0's binary_logloss: 0.462874
# [149]	valid_0's binary_logloss: 0.462876	valid_0's binary_logloss: 0.462876
# [150]	valid_0's binary_logloss: 0.462877	valid_0's binary_logloss: 0.462877
# [151]	valid_0's binary_logloss: 0.462879	valid_0's binary_logloss: 0.462879
# [152]	valid_0's binary_logloss: 0.462907	valid_0's binary_logloss: 0.462907
# [153]	valid_0's binary_logloss: 0.462977	valid_0's binary_logloss: 0.462977
# [154]	valid_0's binary_logloss: 0.462968	valid_0's binary_logloss: 0.462968
# [155]	valid_0's binary_logloss: 0.462961	valid_0's binary_logloss: 0.462961
# [156]	valid_0's binary_logloss: 0.463014	valid_0's binary_logloss: 0.463014
# [157]	valid_0's binary_logloss: 0.462972	valid_0's binary_logloss: 0.462972
# [158]	valid_0's binary_logloss: 0.463003	valid_0's binary_logloss: 0.463003
# [159]	valid_0's binary_logloss: 0.462967	valid_0's binary_logloss: 0.462967
# [160]	valid_0's binary_logloss: 0.463026	valid_0's binary_logloss: 0.463026
# [161]	valid_0's binary_logloss: 0.463039	valid_0's binary_logloss: 0.463039
# [162]	valid_0's binary_logloss: 0.463035	valid_0's binary_logloss: 0.463035
# [163]	valid_0's binary_logloss: 0.463095	valid_0's binary_logloss: 0.463095
# [164]	valid_0's binary_logloss: 0.463161	valid_0's binary_logloss: 0.463161
# [165]	valid_0's binary_logloss: 0.463159	valid_0's binary_logloss: 0.463159
# [166]	valid_0's binary_logloss: 0.463182	valid_0's binary_logloss: 0.463182
# [167]	valid_0's binary_logloss: 0.463185	valid_0's binary_logloss: 0.463185
# [168]	valid_0's binary_logloss: 0.463165	valid_0's binary_logloss: 0.463165
# [169]	valid_0's binary_logloss: 0.463165	valid_0's binary_logloss: 0.463165
# [170]	valid_0's binary_logloss: 0.463234	valid_0's binary_logloss: 0.463234
# [171]	valid_0's binary_logloss: 0.463219	valid_0's binary_logloss: 0.463219
# [172]	valid_0's binary_logloss: 0.46319	valid_0's binary_logloss: 0.46319
# [173]	valid_0's binary_logloss: 0.463145	valid_0's binary_logloss: 0.463145
# [174]	valid_0's binary_logloss: 0.46318	valid_0's binary_logloss: 0.46318
# [175]	valid_0's binary_logloss: 0.463139	valid_0's binary_logloss: 0.463139
# [176]	valid_0's binary_logloss: 0.463171	valid_0's binary_logloss: 0.463171
# [177]	valid_0's binary_logloss: 0.463126	valid_0's binary_logloss: 0.463126
# [178]	valid_0's binary_logloss: 0.463091	valid_0's binary_logloss: 0.463091
# [179]	valid_0's binary_logloss: 0.462988	valid_0's binary_logloss: 0.462988
# [180]	valid_0's binary_logloss: 0.462997	valid_0's binary_logloss: 0.462997
# [181]	valid_0's binary_logloss: 0.462969	valid_0's binary_logloss: 0.462969
# [182]	valid_0's binary_logloss: 0.463008	valid_0's binary_logloss: 0.463008
# [183]	valid_0's binary_logloss: 0.462941	valid_0's binary_logloss: 0.462941
# [184]	valid_0's binary_logloss: 0.462911	valid_0's binary_logloss: 0.462911
# [185]	valid_0's binary_logloss: 0.462912	valid_0's binary_logloss: 0.462912
# [186]	valid_0's binary_logloss: 0.462928	valid_0's binary_logloss: 0.462928
# [187]	valid_0's binary_logloss: 0.462825	valid_0's binary_logloss: 0.462825
# [188]	valid_0's binary_logloss: 0.462823	valid_0's binary_logloss: 0.462823
# [189]	valid_0's binary_logloss: 0.462808	valid_0's binary_logloss: 0.462808
# [190]	valid_0's binary_logloss: 0.462866	valid_0's binary_logloss: 0.462866
# [191]	valid_0's binary_logloss: 0.462877	valid_0's binary_logloss: 0.462877
# [192]	valid_0's binary_logloss: 0.462931	valid_0's binary_logloss: 0.462931
# [193]	valid_0's binary_logloss: 0.463008	valid_0's binary_logloss: 0.463008
# [194]	valid_0's binary_logloss: 0.462999	valid_0's binary_logloss: 0.462999
# [195]	valid_0's binary_logloss: 0.463028	valid_0's binary_logloss: 0.463028
# [196]	valid_0's binary_logloss: 0.463087	valid_0's binary_logloss: 0.463087
# [197]	valid_0's binary_logloss: 0.463063	valid_0's binary_logloss: 0.463063
# [198]	valid_0's binary_logloss: 0.46308	valid_0's binary_logloss: 0.46308
# [199]	valid_0's binary_logloss: 0.463068	valid_0's binary_logloss: 0.463068
# [200]	valid_0's binary_logloss: 0.463098	valid_0's binary_logloss: 0.463098
# [201]	valid_0's binary_logloss: 0.463124	valid_0's binary_logloss: 0.463124
# [202]	valid_0's binary_logloss: 0.463108	valid_0's binary_logloss: 0.463108
# [203]	valid_0's binary_logloss: 0.463264	valid_0's binary_logloss: 0.463264
# [204]	valid_0's binary_logloss: 0.463268	valid_0's binary_logloss: 0.463268
# [205]	valid_0's binary_logloss: 0.463221	valid_0's binary_logloss: 0.463221
# [206]	valid_0's binary_logloss: 0.463236	valid_0's binary_logloss: 0.463236
# [207]	valid_0's binary_logloss: 0.463206	valid_0's binary_logloss: 0.463206
# [208]	valid_0's binary_logloss: 0.463279	valid_0's binary_logloss: 0.463279
# [209]	valid_0's binary_logloss: 0.463231	valid_0's binary_logloss: 0.463231
# [210]	valid_0's binary_logloss: 0.463234	valid_0's binary_logloss: 0.463234
# [211]	valid_0's binary_logloss: 0.463226	valid_0's binary_logloss: 0.463226
# [212]	valid_0's binary_logloss: 0.463203	valid_0's binary_logloss: 0.463203
# [213]	valid_0's binary_logloss: 0.463249	valid_0's binary_logloss: 0.463249
# [214]	valid_0's binary_logloss: 0.463257	valid_0's binary_logloss: 0.463257
# [215]	valid_0's binary_logloss: 0.463202	valid_0's binary_logloss: 0.463202
# Early stopping, best iteration is:
# [115]	valid_0's binary_logloss: 0.46262	valid_0's binary_logloss: 0.46262
# AUC: 0.8539700886428475
# ACC: 0.78259

# %%
submission = pd.DataFrame({'PassengerId':test.index,'Survived':lgbm_test_pred})
submission['Survived'] = (submission['Survived'] > 0.5).astype(int)
submission.to_csv('submission.csv', index=False)

# %%
plt.rcParams["figure.figsize"] = (6, 5)
lightgbm.plot_importance(lgbm_wrapper,max_num_features = 16,height=.9)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# <a id="base_model_tree"></a>
# ### (2) Base Model - Decision Tree
# - Let's create Base Model
# - Model Evaluation is [Accuracy](https://www.kaggle.com/c/tabular-playground-series-apr-2021/overview/evaluation)
#     + If you want to know more, please see https://en.wikipedia.org/wiki/Accuracy_and_precision#In_binary_classification

# %%
from sklearn.metrics import accuracy_score
def acc_score(y_true, y_pred, **kwargs):
    return accuracy_score(y_true, (y_pred > 0.5).astype(int), **kwargs)

# %% [markdown]
# - Let's evaluate of base model using validation set
# - AUC & Accurarcy are measured at this moment.

# %%
tree_model = DecisionTreeClassifier(max_depth=3)
tree_model.fit(X_train, y_train)
predictions = tree_model.predict_proba(X_val)
AUC = roc_auc_score(y_val, predictions[:,1])
ACC = acc_score(y_val, predictions[:,1])
print("Model AUC:", AUC)
print("Model Accurarcy:", ACC)
print("\n")

fpr, tpr, _ = roc_curve(y_val, predictions[:,1])

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(fpr, tpr)
ax.text(x = 0.3, 
        y = 0.4, 
        s = "Model AUC is {}\n\nModel Accuracy is {}".format(np.round(AUC, 2), np.round(ACC, 2)), 
        fontsize=16, bbox=dict(facecolor='gray', alpha=0.3))
ax.set_xlabel('FPR')
ax.set_ylabel('TPR')
ax.set_title('ROC curve')

plt.show()

# %% [markdown]
# - Good, great.
# - Now, we finally submit file to competition.
# - `.5` Threshold could be different, depending upon your assumption.
#     + If you are not familar with the concept Threshold, then please read this article. https://developers.google.com/machine-learning/crash-course/classification/thresholding

# %%
final_preds = tree_model.predict(test_data)
binarizer = np.vectorize(lambda x: 1 if x >= .5 else 0)
prediction_binarized = binarizer(final_preds)
submission = pd.concat([sample_submission,pd.DataFrame(prediction_binarized)], axis=1).drop(columns=['Survived'])
submission.columns = ['PassengerId', 'Survived']
submission.to_csv('tree_base_submission.csv', index=False)

# %% [markdown]
# <a id="helper_class"></a>
# ### (3) Create Helper Class and Submission Function
# - we need to create helper class with common tasks such as model, train, predict, fit, feature_importance, and even ROC Curve Graph
# -

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, confusion_matrix
from matplotlib import pyplot as plt

SEED = 0 # for Reproducibility

# class 
class sk_helper(object):
    def __init__(self, model, seed = 0, params={}):
        params['random_state'] = seed
        self.model = model(**params)
        self.model_name = str(model).split(".")[-1][:-2]
        
    # train
    def train(self, X_train, y_train):
        self.model.fit(X_train, y_train)
        
    # predict
    def predict(self, y_val):
        return self.model.predict(y_val)
    
    # inner fit
    def fit(self, x, y):
        return self.model.fit(x, y)
    
    # feature importance
    def feature_importances(self, X_train, y_train):
        return self.model.fit(X_train, y_train).feature_importances_
        
    # roc_curve
    def roc_curve_graph(self, X_train, y_train, X_val, y_val):
        self.model.fit(X_train, y_train)
        
        print("model_name:", self.model_name)
        model_name = self.model_name
        preds_proba = self.model.predict_proba(X_val)
        preds = (preds_proba[:, 1] > 0.5).astype(int)
        auc = roc_auc_score(y_val, preds_proba[:, 1])
        acc = accuracy_score(y_val, preds)
        confusion = confusion_matrix(y_val, preds)
        print('Confusion Matrix')
        print(confusion)
        print("Model AUC: {0:.3f}, Model Accuracy: {1:.3f}\n".format(auc, acc))
        fpr, tpr, _ = roc_curve(y_val, predictions[:,1])
        fig, ax = plt.subplots(figsize=(10, 6))

        ax.plot(fpr, tpr)
        ax.text(x = 0.3, 
                y = 0.4, 
                s = "Model AUC is {}\n\nModel Accuracy is {}".format(np.round(auc, 2), np.round(acc, 2)), 
                fontsize=16, bbox=dict(facecolor='gray', alpha=0.3))
        ax.set_xlabel('FPR')
        ax.set_ylabel('TPR')
        ax.set_title('ROC curve of {}'.format(model_name), fontsize=16)

        plt.show()

# %% [markdown]
# - Now, Let's test if this works or not

# %% [markdown]
# <a id="DecisionTreeClassifier"></a>
# #### (A) DecisionTreeClassifier
# - This is DecisionTreeClassifier Model from [sklearn.tree.DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html).

# %%
# %%time
tree_params = {'max_depth': 6}

tree_model = sk_helper(model=DecisionTreeClassifier, seed=SEED, params=tree_params)
tree_model.roc_curve_graph(X_train, y_train, X_val, y_val)

# %% [markdown]
# <a id="RandomForestClassifier"></a>
# #### (B) RandomForestClassifier
# - This is RandomForestClassifier Model from [sklearn.tree.DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html).

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier

rf_params = {
    'n_jobs': -1,
    'n_estimators': 500,
     'warm_start': True, 
     #'max_features': 0.2,
    'max_depth': 6,
    'min_samples_leaf': 2,
    'max_features' : 'sqrt',
    'verbose': 1
}

rf_model = sk_helper(model=RandomForestClassifier, seed=SEED, params=rf_params)
rf_model.roc_curve_graph(X_train, y_train, X_val, y_val)

# %% [markdown]
# <a id="lightgbm"></a>
# #### (C) LightGBM
# - Let's implement LightGBM with best parameters. You can found it here: https://www.kaggle.com/jmargni/tps-apr-2021-lightgbm-optuna

# %%
# %%time

import lightgbm
from lightgbm import LGBMClassifier
print(lightgbm.__version__)
lgb_params = {
    'metric': 'auc',
    'n_estimators': 10000,
    'objective': 'binary',
}

lgb_model = sk_helper(model=LGBMClassifier, seed=SEED, params=lgb_params)
lgb_model.roc_curve_graph(X_train, y_train, X_val, y_val)

# %% [markdown]
# <a id="feature_importance"></a>
# #### (D) Feature Importance
# - Let's draw graph feature importance plot

# %%
tree_features = tree_model.feature_importances(X_train, y_train)
rf_features = rf_model.feature_importances(X_train, y_train)
lgb_features = lgb_model.feature_importances(X_train, y_train)

# %%
cols = X.columns.values
feature_df = pd.DataFrame({'features': cols, 
                          'Decision Tree': tree_features, 
                          'RandomForest': rf_features, 
                          'LightGBM': lgb_features})

feature_df

# %%
# %matplotlib inline

import seaborn as sb
import matplotlib.pyplot as plt

width = 0.3
x = np.arange(0, len(feature_df.index))

## ax[0] graph
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 16)) # Option sharex=True
ax[0].bar(x - width/2, feature_df['Decision Tree'], color = "#0095FF", width = width)
ax[0].bar(x + width/2, feature_df['RandomForest'], color = "#E6C0B1", width = width)
ax[0].set_xticks(x)
ax[0].set_xticklabels(feature_df['features'], rotation=90)

## ax[0] legend
colors = {'Decision Tree':'#0095FF', 'RandomForest':'#E6C0B1'} 
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]

ax[0].legend(handles, labels, bbox_to_anchor = (0.95, 0.95))
ax[0].set_title("Feature Importance between Decision Tree and RandomForest", fontsize=20)

## ax[1] graph
ax[1].bar(x, feature_df['LightGBM'], color = "#60F09E")
ax[1].set_xticks(x)
ax[1].set_xticklabels(feature_df['features'], rotation=90)
ax[1].set_title("Feature Importance of LightGBM", fontsize=20)

## plt manage
## plt.xticks(x, feature_df['features'], rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Each algorithm provides different feature important values.
#     + If you want to know this concept further, please read this article: [How to Calculate Feature Importance With Python](https://machinelearningmastery.com/calculate-feature-importance-with-python/)
# - The main goal here is to improve a predictive model, deleting some features. For example, feature SisSp and Parch in both algorithm are not quite important. So, At this moment, we can delete them.
#     + This code will be worked with feature engineering section.

# %% [markdown]
# ###

# %% [markdown]
# <a id="submission"></a>
# #### (E) Submission
# - Now, we create submission function.

# %%
import numpy as np
from datetime import datetime

version = datetime.now().strftime("%d-%m-%Y %H-%M-%S")

def final_submission(model, data, version):
    final_preds = model.predict(data)
    binarizer = np.vectorize(lambda x: 1 if x >= .5 else 0)
    prediction_binarized = binarizer(final_preds)
    submission = pd.concat([sample_submission,pd.DataFrame(prediction_binarized)], axis=1).drop(columns=['Survived'])
    submission.columns = ['PassengerId', 'Survived']
    submission.to_csv('Sklearn of Submit Date {} Submission.csv'.format(version), index=False)
    
final_submission(lgb_model, test_data, version)

# %% [markdown]
# - Now, We will move on `PyCaret` Framework.

# %% [markdown]
# <a id='pycaret'></a>
# ## PyCaret
# ![](https://miro.medium.com/max/2048/1*Cku5-rqmqSIuhUyFkIAdIA.png)
#
# - PyCaret.. Caret in R?
#     + My 1st reaction on this.. when got heard .. was "is it copy of [caret](https://cran.r-project.org/web/packages/caret/vignettes/caret.html) package in R?"
#
# - Let's look at this framework.

# %% [markdown]
# <a id="intro"></a>
# ### (1) Intro
# - URL: https://pycaret.org/about/
# > It's an open source low-code machine learning library that aims to reduce cycle time from hypothesis to insights.
#
# - Point 1. Simple and Easy to use
# > All the operations performed in PyCaret are automatically stored in a custom `Pipeline` that is fully orchestrated for `deployment`.
# - Point 2. Python Wrapper
# > Around several machine learning libraries and frameworks such as scikit-learn, XGBoost, Microsoft LightGBM, spaCy and many more.
# - Point 3. Train Multiple Models
# > It trains multiple models SIMULTANEOUSLY.. (interesting!) and outputs a table comparing performaces of each model you developed.
# - Point 4. [PyCaret on GPU](https://pycaret.readthedocs.io/en/latest/installation.html)
# > `PyCaret >= 2.2` provides the option to use GPU for select model training and hyperparameter tuning. There is no change in the use of the API, however, in some cases, additional libraries have to be installed as they are not installed with the default slim version or the full version. The following estimators can be trained on GPU.

# %% [markdown]
# <a id="pycaret_tutorials"></a>
# ### (2) PyCaret Tutorials
# - If you want to learn some basic tutorials, then please visit here: https://pycaret.readthedocs.io/en/latest/tutorials.html
#      + I will skip out introducing some basic codes here.

# %% [markdown]
# <a id="base_model"></a>
# ### (3) Base Model
# - Unfortunately, if you want to use this framework, then you should install it with following command.
# > !pip install pycaret
#
# - It will take a few minutes.

# %% [markdown]
# - We will downgrade it this since we are going to use PyCaret. Some issues are reported.
#     + https://github.com/pycaret/pycaret/issues/1140

# %%
# !pip uninstall scikit-learn -y
# !pip install pycaret==2.2.3

# %% [markdown]
# - Let's check version

# %%
# check version
from pycaret.utils import version
import sklearn
print("pycaret version:", version())
print("sklearn version:", sklearn.__version__)

# %% [markdown]
# <a id="initialize_setup"></a>
# #### (A) Initialize Setup
# - Before you train, you need to setup with following code.
# - Here, We need to combine two dataframe, X and y and stored it as train_data

# %%
all_df_pycaret = pd.concat([X, y], axis=1)
all_df_pycaret['Survived'] = all_df_pycaret['Survived'].astype('int64')
all_df_pycaret.info()

# %% [markdown]
# - This code is simple but very powerful.
# - If you want to study more setting up more options such as Data Preparation, Scale and Transformation, and Feature Engineering, Feature Selection. Then please visit here: https://pycaret.org/train-test-split/

# %%
from pycaret.classification import *

setup(data = all_df_pycaret, 
      target = 'Survived', 
      fold = 3,
      silent = True
     )

# %% [markdown]
# <a id="compare_models"></a>
# #### (B) Comparing All Models
# - This is starting point to recommend a model, evaluating performaces of all models when the setup is completed.
# - This function trains all models in the model library and scores them using stratified cross validation for metric evaluation.

# %%
# %%time

best_model = compare_models(sort = 'Accuracy', n_select = 3)

# %%
print(best_model)

# %% [markdown]
# - To me, the best model is `Gradient Boosting Classifier`
# - So, We will create GBC model in this tutorial.

# %% [markdown]
# <a id="create_pycaret_model"></a>
# #### (C) Create Model
# - This function creates a model and scores it using Stratified Cross Validation.The output prints a score grid that shows Accuracy, AUC, Recall, Precision, F1, Kappa and MCC by fold (default = 10 Fold). This function returns a trained model object.
# - You can create different models here.
#     + Examples: https://pycaret.org/classification/
#
# ```python
# # train logistic regression model
# lr = create_model('lr') #lr is the id of the model
# # check the model library to see all models
# models()
# # train rf model using 5 fold CV
# rf = create_model('rf', fold = 5)
# # train svm model without CV
# svm = create_model('svm', cross_validation = False)
# # train xgboost model with max_depth = 10
# xgboost = create_model('xgboost', max_depth = 10)
# # train xgboost model on gpu
# xgboost_gpu = create_model('xgboost', tree_method = 'gpu_hist', gpu_id = 0) #0 is gpu-id
# # train multiple lightgbm models with n learning_rate<br>import numpy as np
# lgbms = [create_model('lightgbm', learning_rate = i) for i in np.arange(0.1,1,0.1)]
# # train custom model
# from gplearn.genetic import SymbolicClassifier
# symclf = SymbolicClassifier(generation = 50)
# sc = create_model(symclf)
# ```

# %%
# %%time
gbc_model = create_model('gbc')

# %% [markdown]
# <a id="tune_pycaret_model"></a>
# #### (D) Tune Model
# - This function tunes the hyperparameters of a model and scores it using Stratified Cross Validation. The output prints a score grid that shows Accuracy, AUC, Recall Precision, F1, Kappa, and MCCby fold (by default = 10 Folds). This function returns a trained model object.
#     + Examples: https://pycaret.org/classification/#tune-model
#
# ```python
# # train a decision tree model with default parameters
# dt = create_model('dt')
#
# # tune hyperparameters of decision tree
# tuned_dt = tune_model(dt)
#
# # tune hyperparameters with increased n_iter
# tuned_dt = tune_model(dt, n_iter = 50)
#
# # tune hyperparameters to optimize AUC
# tuned_dt = tune_model(dt, optimize = 'AUC') #default is 'Accuracy'
#
# # tune hyperparameters with custom_grid
# params = {"max_depth": np.random.randint(1, (len(data.columns)*.85),20),
#           "max_features": np.random.randint(1, len(data.columns),20),
#           "min_samples_leaf": [2,3,4,5,6],
#           "criterion": ["gini", "entropy"]
#           }
#
# tuned_dt_custom = tune_model(dt, custom_grid = params)
#
# # tune multiple models dynamically
# top3 = compare_models(n_select = 3)
# tuned_top3 = [tune_model(i) for i in top3]
# ```

# %%
# %%time
tuned_gbc = tune_model(gbc_model, n_iter = 50)

# %% [markdown]
# <a id = "plot_pycaret_model"></a>
# #### (E) Plot Model
# - This function takes a trained model object and returns a plot based on the test / hold-out set. The process may require the model to be re-trained in certain cases. See list of plots supported below. Model must be created using create_model() or tune_model().
#     + Examples: https://pycaret.org/classification/#plot-model
#
# ```python
# #create a model
# lr = create_model('lr')
# #plot a model
# plot_model(lr)
# ```
#
# - Many options are avaiable.

# %%
plot_model(tuned_gbc, plot = 'confusion_matrix')

# %%
plot_model(tuned_gbc, plot = 'feature_all')

# %%
plot_model(tuned_gbc, plot = 'auc')

# %% [markdown]
# <a id="preds_submissions"></a>
# #### (F) Predictions and Submissions
# - Now, it's time to predict and submit it.

# %%
predictions = predict_model(tuned_gbc, data = test_data)
predictions.info()

# %%
submission = pd.read_csv(BASE_DIR + 'sample_submission.csv')
submission['Survived'] = predictions['Label']
submission.to_csv('PyCaret Submission.csv', index=False)
submission.head()

# %% [markdown]
# - Finally Done. I will review the framework later.

# %% [markdown]
# ####
